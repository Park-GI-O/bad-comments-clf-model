# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import re
import matplotlib.font_manager as fm

from konlpy.tag import Okt
from PIL import Image
from collections import Counter
from wordcloud import WordCloud
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

warnings.filterwarnings('ignore')
plt.rcParams['font.family'] = 'NanumSquare'

# %%
# hate : 0
# none : 1

# %% [markdown]
# # Data load

# %%
data1 = pd.read_csv('data/data1.csv', sep='\t')
data1
# Out:
#                                                 content  lable
# 0     이종석 한효주 나오는 드라마 이후로 드라마 안봤다. 2년전인가?? 좀 신선했었지. ...    0.0
# 1                       씨바알..노무노무 술프노... 오늘 저녁은 꽂등심이다ㅠㅜ    0.0
# 2                                              짱깨 꺼라ㅡ패쓰    0.0
# 3     그들의 사생활 ~ 고인이된 설리를 위해서라도 모두 조용하길 지금 누굴 탓한다고 무슨...    1.0
# 4     아무리 법이 뭣같아도 무슨 자격으로 개인의 신상정보를 불특정 다수에게 공개하는지 도...    1.0
# ...                                                 ...    ...
# 9995                      이거 보다 더한 막장의 드라마도 넋놓고 보면서 무슨?    1.0
# 9996                                  머...제네시스..올라프에디션?    1.0
# 9997                        항상 여자로 ㅡ ㅡ 저지랄 들이야 남자들 벗겨봐라    0.0
# 9998  첫번째 이유가 ㄹㅇ 맞지특히나 뉴스나 기사 몇줄읽은 학생들끼리 대화해도 서로 존나 ...    0.0
# 9999                     Lg폰 누가쓰냐 gps도 못잡는폰 쓰래기 통에나 버려라    0.0
#
# [10000 rows x 2 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  10000 non-null  object
#  1   lable    9975 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 156.4+ KB

# %% [markdown]
# # Preprocessing

# %%
data1 = data1.rename(columns={'lable':'label'})

# %%
null_data = data1[data1['label'].isnull()]
null_data['label'] = null_data['content'].str.split('\t').str[1]
null_data['content'] = null_data['content'].str.split('\t').str[0]
null_data
# Out:
#                                                 content label
# 1602  응애 응애 엄마 저 맘에 안들죠? ........아들 ?? " 너 내가 우스워 보이...     0
# 1654            토니스타크 평소 "아이엠그루트"라는 유행어를 부러워했다는게 학계의 정설     1
# 1992  "13일 현대차에 따르면 올 들어 국내 소비자들의 수입차 구매의향률이 3년 만에 하...     1
# 2920                  에이프릴이 한마디 합니다 "예쁜게 죄" 구하라님 "무기징역"     1
# 3720           답글 글씨체를 봐라 저게 애새끼가 쓴거냐?"빨갱이새끼가 쓴거지 ㅁㅈㅎㅉㅉ     0
# 3807  알겠다이기ㅋㅋ 딱 채찍쳐맞는거 좋아하는 한국식 마인드네. 노예마인드. 조금만 성공한...     0
# 3908            이래서 스스로 걸리거든 "죄인들이"~ㅎㅎㅎ 재미보고 털리고 그치~~~?     0
# 4241  아버지는 내재된 악마들을 다룰 정신적 힘을 가지고 있지 않았다." 이 말한마디가 사...     1
# 4283  댓글 중 "선동 당해서 촞불든 개돼지 홍어들도 단죄를 받아야 할 공범자들이다"에100ㅂ!     0
# 5000  스파이 제안받고 살해 안당하는 법1. 처음에 스파이 제안을 받았을때 "중국을 위해서...     0
# 5521    "국방부 "까지 ㅡㄱ ㅐ 엿같은 ㅈ ㅣ랄주댕이...좌빨에서 ㅡ인민군대로 ㅡ가려는건가?     0
# 5866  쌩뚱맞게 60대최반엌 치매라니 그것도 곱게 사는 사모님이- -" 알콜중독도 아니고 ...     0
# 6477  페미메퇘지쿵쾅년인 메갈페미들은 니들이 좋아하는 싫어요 ㄱㄱ제발부탁해~~"일반 여성"...     0
# 6538  아니 ㅆㅂ 그런 "카더라"가 넘쳐난다고 그거에 대해서 혹시 댓글게이는 뭔가 아는거 ...     0
# 6771  저 때 투니버스에서 코요태 짧게 인터뷰 했었는데 김종민이 "노래는 뭐 신지가 다 하...     1
# 6932                개 족 가튼 국방부의 "휴기연장콜센터"발족을 축하한다 ㅆ ㅂ..     0
# 7199  민족적 자존심과 애국심을 갖고 국산품 이용합시다 . . . "겸손"한 마음으로 재산...     1
# 7252  아나운서는 목표가 아니었지ㅋㅋ재벌하고 결혼하자마자 바로 은퇴하네ㅋㅋ무슨 인터뷰한 거...     0
# 7270  결국 준영과 다솜은 바람을 피게되고 무인도로 떠난다에 한표 ㅋㅋㅋ 자연인이 되어 "...     1
# 7480  지금 연락하는 여자랑 폰섹 엄청 많이했는데만나서 호텔 들어가서침대에 서로 마주보고 ...     0
# 7499  몽골한테 "최근에" 250년간 지배당하고 집단강간을 당했는데 동양피가 하나도 안섞였...     0
# 7887  뭐 선천적으로 여성스럽거나 여자역할을 하고 싶어하는 동성애자들 그럴 수 있다고는 생...     0
# 9666          ㄹㅇ 시발 그냥 "다른 진로 생각해 보세요"라고만 했어도 욕 안처 먹었지.     0
# 9698                               간만에 이단어가 떠오르는군 "이뭐병"     0
# 9875  노라조 "형"이란 노래로 힘들 때 위로를 받곤 했습니다. 앞으로도 노라조라는 이름으...     1

# %%
df1 = pd.concat([data1, null_data])
df1.dropna(axis=0, inplace=True)
df1 = df1.astype({'label':'int'})
df1 = df1.reset_index(drop=True)
df1
# Out:
#                                                 content  label
# 0     이종석 한효주 나오는 드라마 이후로 드라마 안봤다. 2년전인가?? 좀 신선했었지. ...      0
# 1                       씨바알..노무노무 술프노... 오늘 저녁은 꽂등심이다ㅠㅜ      0
# 2                                              짱깨 꺼라ㅡ패쓰      0
# 3     그들의 사생활 ~ 고인이된 설리를 위해서라도 모두 조용하길 지금 누굴 탓한다고 무슨...      1
# 4     아무리 법이 뭣같아도 무슨 자격으로 개인의 신상정보를 불특정 다수에게 공개하는지 도...      1
# ...                                                 ...    ...
# 9995  몽골한테 "최근에" 250년간 지배당하고 집단강간을 당했는데 동양피가 하나도 안섞였...      0
# 9996  뭐 선천적으로 여성스럽거나 여자역할을 하고 싶어하는 동성애자들 그럴 수 있다고는 생...      0
# 9997          ㄹㅇ 시발 그냥 "다른 진로 생각해 보세요"라고만 했어도 욕 안처 먹었지.      0
# 9998                               간만에 이단어가 떠오르는군 "이뭐병"      0
# 9999  노라조 "형"이란 노래로 힘들 때 위로를 받곤 했습니다. 앞으로도 노라조라는 이름으...      1
#
# [10000 rows x 2 columns]

# %%
data2 = pd.read_csv('data/data2.txt', sep='\t')
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7896 entries, 0 to 7895
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   comments             7896 non-null   object
#  1   contain_gender_bias  7896 non-null   bool
#  2   bias                 7896 non-null   object
#  3   hate                 7896 non-null   object
# dtypes: bool(1), object(3)
# memory usage: 192.9+ KB

# %%
data2.drop(['contain_gender_bias', 'bias'], axis=1, inplace=True)

# %%
data2['hate'].value_counts()
# Out:
# none         3486
# offensive    2499
# hate         1911
# Name: hate, dtype: int64

# %%
data2.replace({'hate':0, 'none': 1, 'offensive':0}, inplace=True)

# %%
data2 = data2.rename(columns={'comments':'content', 'hate':'label'})

# %%
data2['label'].value_counts()
# Out:
# 0    4410
# 1    3486
# Name: label, dtype: int64

# %%
df = pd.concat([df1, data2])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17896 entries, 0 to 7895
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  17896 non-null  object
#  1   label    17896 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 419.4+ KB

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#                                              content  label
# 0  이종석 한효주 나오는 드라마 이후로 드라마 안봤다. 2년전인가?? 좀 신선했었지. ...      0
# 1                    씨바알..노무노무 술프노... 오늘 저녁은 꽂등심이다ㅠㅜ      0
# 2                                           짱깨 꺼라ㅡ패쓰      0
# 3  그들의 사생활 ~ 고인이된 설리를 위해서라도 모두 조용하길 지금 누굴 탓한다고 무슨...      1
# 4  아무리 법이 뭣같아도 무슨 자격으로 개인의 신상정보를 불특정 다수에게 공개하는지 도...      1

# %%
content_list = []

for content in df['content'] :
    content = re.sub("[^0-9가-힣ㄱ-ㅎㅏ-ㅣ\\s]","", content)
    content_list.append(content)

# %%
df['content'] = content_list

# %%
df
# Out:
#                                                  content  label
# 0      이종석 한효주 나오는 드라마 이후로 드라마 안봤다 2년전인가 좀 신선했었지 근데 이...      0
# 1                             씨바알노무노무 술프노 오늘 저녁은 꽂등심이다ㅠㅜ      0
# 2                                               짱깨 꺼라ㅡ패쓰      0
# 3      그들의 사생활  고인이된 설리를 위해서라도 모두 조용하길 지금 누굴 탓한다고 무슨소...      1
# 4      아무리 법이 뭣같아도 무슨 자격으로 개인의 신상정보를 불특정 다수에게 공개하는지 도...      1
# ...                                                  ...    ...
# 17891                                         힘내세요 응원합니다      1
# 17892                                 힘내세요삼가 고인의 명복을 빕니다      1
# 17893                                   힘내세용  항상 응원합니닷        1
# 17894      힘내소연기로 답해요나도 53살 인데 이런일 저런일 다 있더라구요인격을 믿습니다홨팅      1
# 17895                                 힘들면 관뒀어야지 그게 현명한거다      1
#
# [17896 rows x 2 columns]

# %%
df.to_csv('data/hate_data.csv', index=False)

# %%
hate_data = pd.read_csv('data/hate_data.csv')
hate_data.drop_duplicates(subset=['content'], inplace=True)
hate_data.reset_index(drop=True)
# Out:
#                                                  content  label
# 0      이종석 한효주 나오는 드라마 이후로 드라마 안봤다 2년전인가 좀 신선했었지 근데 이...      0
# 1                             씨바알노무노무 술프노 오늘 저녁은 꽂등심이다ㅠㅜ      0
# 2                                               짱깨 꺼라ㅡ패쓰      0
# 3      그들의 사생활  고인이된 설리를 위해서라도 모두 조용하길 지금 누굴 탓한다고 무슨소...      1
# 4      아무리 법이 뭣같아도 무슨 자격으로 개인의 신상정보를 불특정 다수에게 공개하는지 도...      1
# ...                                                  ...    ...
# 12980            희철이가 트와이스 사귀는거 보고 트와이스 하나 노리나 보다 ㅋㅋㅋㅋㅋㅋ      1
# 12981                     히든싱어도 끝났다예전에 비해 가수의 레벨이 너무 떨어짐      0
# 12982                  히잌 기저귀 찬 년들이 군대 군대 주댕이 털고 자빠졌노ㅋ        0
# 12983  히트작이래봐야 미사 발리 두개 정도가 다고 연기력도 그저 그런 수준으로 배우로서 명...      0
# 12984                         힘내라 이쁜 혜선아 다음엔 저런인간 만나지 말고      0
#
# [12985 rows x 2 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# ## 워드클라우드

# %%
hate_data_0 = hate_data[hate_data['label'] == 0]
hate_data_1 = hate_data[hate_data['label'] == 1]

# %%
comments = hate_data_0["content"].to_string()

# %%
okt = Okt()
nouns = okt.nouns(comments) # 명사만 추출

# %%
df_word_0 = pd.DataFrame({'word':nouns})
df_word_0['count'] = df_word_0['word'].str.len()
df_word_0 = df_word_0.query('count >= 2')

# %%
df_word_0 = df_word_0.groupby('word', as_index = False).agg(n = ('word', 'count')).sort_values('n', ascending = False)
top20_0 = df_word_0.head(20)

# %%
# 데이터 프레임을 딕셔너리로 변환(워드클라우드는 단어는 키, 빈도는 값으로 구성된 딕셔너리 자료 구조를 이용해 만듦. df_word는 데이터프레임이므로 딕셔너리로 변환해야 함)
dic_word_0 = df_word_0.set_index('word').to_dict()['n']

# wc 만들기
from wordcloud import WordCloud
wc = WordCloud(font_path='malgun',
               width = 400,                 # 가로 크기
               height = 400,                # 세로 크기
               background_color = 'white')  # 배경색

# 워드 클라우드 만들기
img_wordcloud = wc.generate_from_frequencies(dic_word_0)

# 워드 클라우드 출력하기
plt.figure(figsize = (10, 10))  # 가로, 세로 크기 설정
plt.axis('off')                 # 테두리 선 없애기
plt.imshow(img_wordcloud)       # 워드 클라우드 출력
plt.show()

# %%
comments = hate_data_1["content"].to_string()

# %%
okt = Okt()
nouns = okt.nouns(comments) # 명사만 추출

# %%
df_word_1 = pd.DataFrame({'word':nouns})
df_word_1['count'] = df_word_1['word'].str.len()
df_word_1 = df_word_1.query('count >= 2')

# %%
df_word_1 = df_word_1.groupby('word', as_index = False).agg(n = ('word', 'count')).sort_values('n', ascending = False)
top20_1 = df_word_1.head(20)

# %%
# 데이터 프레임을 딕셔너리로 변환(워드클라우드는 단어는 키, 빈도는 값으로 구성된 딕셔너리 자료 구조를 이용해 만듦. df_word는 데이터프레임이므로 딕셔너리로 변환해야 함)
dic_word_1 = df_word_1.set_index('word').to_dict()['n']

# wc 만들기
from wordcloud import WordCloud
wc = WordCloud(font_path='malgun',
               width = 400,                 # 가로 크기
               height = 400,                # 세로 크기
               background_color = 'white')  # 배경색

# 워드 클라우드 만들기
img_wordcloud = wc.generate_from_frequencies(dic_word_1)

# 워드 클라우드 출력하기
plt.figure(figsize = (10, 10))  # 가로, 세로 크기 설정
plt.axis('off')                 # 테두리 선 없애기
plt.imshow(img_wordcloud)       # 워드 클라우드 출력
plt.show()

# %%
# comments를 string 형태로 변환
comments = df["content"].to_string()

# %%
okt = Okt()
nouns = okt.nouns(comments) # 명사만 추출

# %%
# 데이터 프레임으로 변환
df_word = pd.DataFrame({'word':nouns})
df_word.head()
# Out:
#   word
# 0  이종석
# 1  한효주
# 2  드라마
# 3   이후
# 4  드라마

# %%
df_word['count'] = df_word['word'].str.len()
df_word.head()
# Out:
#   word  count
# 0  이종석      3
# 1  한효주      3
# 2  드라마      3
# 3   이후      2
# 4  드라마      3

# %%
# 두글자 이상 단어만 남기기
df_word = df_word.query('count >= 2')
df_word.sort_values('count').head()
# Out:
#       word  count
# 49790   만도      2
# 61783   기부      2
# 61784   검색      2
# 61785   한번      2
# 61786   광고      2

# %%
## 단어 빈도 구하기
df_word = df_word.groupby('word', as_index = False) \
                 .agg(n = ('word', 'count')) \
                 .sort_values('n', ascending = False)
df_word.head()
# Out:
#      word    n
# 4889   사람  806
# 6933   여자  804
# 9665   진짜  803
# 1758   남자  478
# 1089   그냥  411

# %%
# # 단어 빈도 상위 100개 추출
# top100 = df_word.head(100)
# top100

# 단어 빈도 상위 100개 추출
top20 = df_word.head(20)
top20
# Out:
#       word    n
# 4889    사람  806
# 6933    여자  804
# 9665    진짜  803
# 1758    남자  478
# 1089    그냥  411
# 5138    새끼  397
# 541     결혼  348
# 6996    연기  333
# 6767    얼굴  328
# 1240    기사  326
# 2649   드라마  308
# 5167    생각  306
# 4329    보고  296
# 8089    이제  283
# 8927    정말  266
# 2342    댓글  253
# 7030   연예인  247
# 11152   하나  242
# 11255   한국  240
# 4044    방송  232

# %%
dic_word = df_word.set_index('word').to_dict()['n']
dic_word

# wc 만들기
from wordcloud import WordCloud
wc = WordCloud(font_path='malgun',
               width = 400,                 # 가로 크기
               height = 400,                # 세로 크기
               background_color = 'white')  # 배경색

# 워드 클라우드 만들기
img_wordcloud = wc.generate_from_frequencies(dic_word)

# 워드 클라우드 출력하기
plt.figure(figsize = (10, 10))  # 가로, 세로 크기 설정
plt.axis('off')                 # 테두리 선 없애기
plt.imshow(img_wordcloud)       # 워드 클라우드 출력
plt.show()

# %%
# 막대 그래프 만들기
plt.figure(figsize=(10, 8))
sns.barplot(data = top20, y = 'word', x = 'n')
plt.show()

# %% [markdown]
# ## n-gram

# %%
df_0 = df[df['label'] == 0]
df_1 = df[df['label'] == 1]

# %%
df_0
# Out:
#                                                  content  label
# 0      이종석 한효주 나오는 드라마 이후로 드라마 안봤다 2년전인가 좀 신선했었지 근데 이...      0
# 1                             씨바알노무노무 술프노 오늘 저녁은 꽂등심이다ㅠㅜ      0
# 2                                               짱깨 꺼라ㅡ패쓰      0
# 5      다음도 들어와라하고다른 의견내는 유튜버 목 자르고추아줌마 꺼 여기저기서 진술나오니무...      0
# 7                              나경아 젖깐사진이나 인스타에 좀올려라 물좀빼게      0
# ...                                                  ...    ...
# 17879                  히잌 기저귀 찬 년들이 군대 군대 주댕이 털고 자빠졌노ㅋ        0
# 17880  히트곡이 없는데 추억팔이가되는 놀라운 조선식 방송국연예매니징ㅋㅋ 기획사 소속사 걍 ...      0
# 17881  히트작이래봐야 미사 발리 두개 정도가 다고 연기력도 그저 그런 수준으로 배우로서 명...      0
# 17882                         힘내라 이쁜 혜선아 다음엔 저런인간 만나지 말고      0
# 17887  힘내세요 한고은님  아래 한남충 글 뭐냐풉평생 연애하나 못하고 홀애비로 살다 가라니...      0
#
# [9410 rows x 2 columns]

# %%
df_1
# Out:
#                                                  content  label
# 3      그들의 사생활  고인이된 설리를 위해서라도 모두 조용하길 지금 누굴 탓한다고 무슨소...      1
# 4      아무리 법이 뭣같아도 무슨 자격으로 개인의 신상정보를 불특정 다수에게 공개하는지 도...      1
# 6                   여자들도 아무한테나 자기야라고하는사람있는데 그것도성희롱인것같은데요      1
# 9                                         지연이 얼굴은 더 배우같네      1
# 10     건축학 개론 지금 다시 봤는데 솔직히 건축학 개론 보다는 아닙니다ㅋ 건축학 개론은 ...      1
# ...                                                  ...    ...
# 17891                                         힘내세요 응원합니다      1
# 17892                                 힘내세요삼가 고인의 명복을 빕니다      1
# 17893                                   힘내세용  항상 응원합니닷        1
# 17894      힘내소연기로 답해요나도 53살 인데 이런일 저런일 다 있더라구요인격을 믿습니다홨팅      1
# 17895                                 힘들면 관뒀어야지 그게 현명한거다      1
#
# [8486 rows x 2 columns]

# %%
df_0['content'] = df_0['content'].str.replace(pat=r'[^\w]', repl=r' ', regex=True)

# %%
m_corpus_0 = []
for t in df_0['content'] :
    m_corpus_0.append(' '.join(okt.morphs(t)))

# %%
stop_words = set(['은', '는', '이', '가', '하', '아', '것', '들', '의', '있', '되', '수', '보', '주', '등', '한'])

# %%
def content_split(content) :
    words_list = []
    for i in content :
        if i != ' ' :
            words_list.append(i)
    return words_list

# %%
def preprocessing(content, okt, remove_stopwords=False, stop_words=[]) :
    word_content = okt.morphs(content, stem=True)
    
    if remove_stopwords :
        word_content = [token for token in word_content if not token in stop_words]
    
    return word_content

# %%
okt = Okt()
clean_df_0 = []

for content in df_0['content'] :
    if type(content) == str :
        clean_df_0.append(preprocessing(content, okt, remove_stopwords=True, stop_words=stop_words))
    else :
        clean_df_0.append([])

# %%
def get_top_ngram(corpus, n=None) :
    vec = CountVectorizer(ngram_range=(n,n)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x : x[1], reverse=True)
    return words_freq[:20]

# %%
top_n_bigrams = get_top_ngram(m_corpus_0, 2)[:20]
x, y = map(list,zip(*top_n_bigrams))

plt.figure(figsize=(8, 6))
ax = sns.barplot(x=y, y=x)
plt.rcParams['font.family'] = 'Malgun Gothic'
ax.set(xlabel='빈도수', ylabel='2gram 형태소')
plt.show()

# %%
top_n_bigrams=get_top_ngram(m_corpus_0,3)[:20] 
x,y=map(list,zip(*top_n_bigrams)) 
ax = sns.barplot(x=y,y=x)
plt.rcParams['font.family'] = 'Malgun Gothic'
ax.set(xlabel = '빈도 수', ylabel = '3gram 형태소')
plt.show()

# %%
m_corpus_1 = []
for t in df_1['content'] :
    m_corpus_1.append(' '.join(okt.morphs(t)))

# %%
plt.figure(figsize=(12, 10))
top_n_bigrams = get_top_ngram(m_corpus_1, 2)[:20]
x, y = map(list,zip(*top_n_bigrams))
ax = sns.barplot(x=y, y=x)
plt.rc('font', size=20)
plt.rcParams['font.family'] = 'Malgun Gothic'
ax.set(xlabel='빈도수', ylabel='2gram 형태소')
plt.show()

# %%
top_n_bigrams = get_top_ngram(m_corpus_1, 3)[:20]
x, y = map(list,zip(*top_n_bigrams))
ax = sns.barplot(x=y, y=x)
# plt.figure(figsize=(8, 6))
# plt.rcParams['font.family'] = 'Malgun Gothic'
ax.set(xlabel='빈도수', ylabel='3gram 형태소')
plt.show()

# %%
plt.figure(figsize=(12, 10))
top_n_bigrams=get_top_ngram(m_corpus_1,3)[:20] 
x,y=map(list,zip(*top_n_bigrams)) 
ax = sns.barplot(x=y,y=x)
plt.rcParams['font.family'] = 'Malgun Gothic'
ax.set(xlabel = '빈도 수', ylabel = '3gram 형태소')
plt.show()

# %% [markdown]
# ## 단어 빈도수

# %%
content_0_list = list(df_0['content'])

# %%
content_0_list
# Out:
# ['이종석 한효주 나오는 드라마 이후로 드라마 안봤다 2년전인가 좀 신선했었지 근데 이런 개막장 드라마는 도대체 누가 보느냐면 변태들이 보는 것이다 정상적인 사람들은 채널을 돌리게 된다',
#  '씨바알노무노무 술프노 오늘 저녁은 꽂등심이다ㅠㅜ',
#  '짱깨 꺼라ㅡ패쓰',
#  '다음도 들어와라하고다른 의견내는 유튜버 목 자르고추아줌마 꺼 여기저기서 진술나오니무슨 기강감찰이니 하며 협박들어가고 댓글에 중국 러시아 욕하는 사람들 이제 아가리 닥쳐라 우리나라도 똑같이 되었다',
#  '나경아 젖깐사진이나 인스타에 좀올려라 물좀빼게',
#  '어린시절 가정교육 못 받은 애들은 절대 그 본성을 숨길수없지',
#  '개별 공무원 뷰웅들의 헷지랄에 뭔 청와대까지 들먹이는지 빠끄네 때도 순시리가 개뻘짓했지 청와대는 암것도 않했지 말입니다',
#  '서열1위네 좆냥이 찍소리도못함ㅋ',
#  '대깨문이 문재인 협박범을 쉴드치네 역시 대가리가 붕어인듯',
#  '예능 보면서 진지 빠는사람 많네 ㅋㅋ극혐 예능은 예능임 저거보고 인성 어쩌고저쩌고 ㅋㅋ어휴 노답',
#  '오 ㄱㅊ노 박 하나 심어놓은다음에 존나패는거',
#  '홍위병들 뭉가 추가 위한다고 아가리 돈이 들어오나',
#  '시어머니 모셔다 친정엄마 생신상도 차려줄건가 제능력껏 하던가 친정엄마까지 모셔다 생고생시키면서 점수따고싶나 골빈건지 철딱서니가 없는건지 나이도 40 이나 먹었구만',
#  '예술병 걸린 힙스터들이 또 오지게 의미부여하고 빨아줄듯',
#  '오로지 냄비가 무기인 오징어썩은 냄새나는 세균덩어리김 치 년 들',
#  '좆냥이주인쉑덜왜 집사집사 ㅇㅈㄹ함 ',
#  '공장가야할새끼들이 재수한다고 지랄 꼴깝을 떨어대니깐 자기도 툭튀어 나오는거지 ㅋㅋ',
#  '처먹는 예능 그만좀 해라예능이랍시고 노이즈 마케팅으로 식당 이용하는것도 아니고',
#  '베트콩들 왜이리 나댑니까',
#  '담배피는 여자연예인들 아갈똥네',
#  '민주당이 압승인데 왜 이런걸로 지랄인지',
#  '방탄소년단도 이제 퇴물됬네 꺼져라 이제 ㅋㅋ',
#  '기독교 목사가 떡치고 다니고',
#  '틀딱이네  먹을 나이 됐다',
#  '우익사쿠라 한국에서 꺼져줘',
#  '문재앙부터 조사가자',
#  '장사해처묵고살기 힘들지 그냥디져',
#  '아 이 개병신새끼씨발ㅋㅋ',
#  '윤은혜는 어쩌고  이 나쁜 꺄',
#  '안할꺼면 글올리지마라 노잼',
#  '그냥 병신 프로그램',
#  '여자살인범들은 거의 비슷한게 있는데 수면유도제 아니면 수면제 농약 청산가리등 독극물이 주로 사용된다는점 우리나라 최초 사이코페스점수 만점을 기록을 기록한 엄인숙이라는 여자 사형수가 있는데 정말 잔인함 우선 무척 미인었다고 하고 순진하게 생겼다고 함 그걸 이용해 남자에게 접근 수면제를 먹이고 잠이들면 바늘로 눈을 찔러 장님을 만든다고 함 그다음 일부러 자빠뜨려 뇌진탕을 만들고 식물인간 상태가 되면 뜨거운 기름을 얼굴에 부었다고 함 그런식으로 상해보험이니 사망보험금이니 타먹으려고 자기 엄마까지 눈을 바늘로 찔러 장님을 만들고 보험금을 타먹은 희대의 싸이코페스년이었음',
#  '아 ㅅㅂ 음주운전 쓰ㄹㅔ기들 걍 뒤져라',
#  'ㅂㄷㅂㄷ 대지말고',
#  '이제 이상민 빚쟁이 캐릭터도 끝난거 아냐이제 블쌍한척 그만해라 솔까 저시키가 빚쟁이들에게 좋은팁 알려줬지 탁재훈은 걍 여자나 꼬시면서 살고 김수미는 왜케 많이 나와 무슨 욕쟁이 할망구 컨셉이냐',
#  '조민기 남자답노 한녀들 참교육 린정한다 오',
#  '여자때문에 남자가피해보네',
#  '난 니 얼굴 보면 ㅈ이 싸그라든다ㅡㅡ',
#  '자꾸 말아먹는데 왜 나오지쟤들 키울 돈으로 나같음 신인그룹 만들겟노 이기야',
#  '게이야 내친구들이 순경이 많은데 순경의 미래는 으떻노 ㅅㅌㅊ노',
#  '저런식의 여론조성은 결국 남자들피해로 돌아옴 나중에 가봐라 진짜후회한다 여가부시발년들은 철지난 성교육으로 ㅈㄴ남자들은 이상성욕자니 니들이 성욕을 해소하는모든방법은 다 불법적이고음성적이다라고하는 마당에 뭐가 해결되겟냐ㅋㅋ 야동사이트도 다 막는 나라다 생각보다 더 병신같은생각을 윗대가리들은 하고있음',
#  '개최국은 자동진출',
#  '혐짤표시해라 ㅅㅂ 기분 더럽노',
#  '정준영이 나이 많아서 너 싫어 하겠는데무슨 헛소리냐',
#  '이와중 타짜는 일본감 ㅋㅋ정신빠진 녀ㄴ',
#  '성형할때부터 뭐지 싶었는데 은근 자존감 낮나 봄 근 10년간 세계를 재패한 빙상 여왕이라 외모따위 개나 주라고 해도 수긍1000만번 할 판국인데 성형하고 남친이 강남',
#  '응 너 똥차 꺼져',
#  '역시 한국인은 남 잘되는 꼴을 못 봐',
#  '얼굴 왜저래',
#  '맨날 못생기고 더럽고 늙은 기안 이시언 같은 한남퇘지들만 나오다가 깨끗하고 깔끔한 풋풋한 남자아이돌 황민현 나오니깐 화면이 달라지는거봐라 그냥 보는거 자체가 재밌음 ㅋㅋ 역시 남자는 잘생기고 어리고 능력있고 봐야함',
#  '하여튼 전라도놈들은 뒷배가 좋아 ㅉㅉ',
#  '사인은 재앙이지 뭐',
#  '저런 새끼는 그냥 무인도에 조두순이랑 둘이살게해라',
#  '좌좀 정서만 없으면 ',
#  '김일성이 중국말 러시아말을 하는 조선족짱깨라메 그거 보고 충격먹음 시발 지금 우리가 중국이랑 싸우고 있다는 거자나',
#  '노무현 실루엣이면 뭐 어쩌라구 놈현이 신이냐아주 어거지네',
#  '계집이란 어차피 사내의 손을 타게되는것을 그리고 사내로 태어나서 계집질도 하는거지 계집년 한두명때문에 대한민국 영화계 거물하나가 또 사라지는구나',
#  '쓰레기는 쓰레기 취급을 당하는구나',
#  '재혼한지는 12주짼데 임신은 32주째면 하여간에',
#  '대가리를 밟혀봐야 정신드는 유형',
#  '어휴 저 쓰레기젤을 빠는넘이있네고추 썪는다',
#  '요즘 신종사기가 이거임틀딱들이 40대 아줌매미 에게결혼하면 10억대 아파트 명의준다고 꼬심알고보면 빚이 10억이상임근데 좋다고 결혼해서 틀니노후 뒤치닥거리함물론 틀니뒤지면 이자못내서 나앉음노후대책 ㅆㅅㅌㅊ',
#  '기자 제목 다는 꼬라지도 극혐 어휴 여자네',
#  '저의자 내구도 존나 의심됨ㅋ글고 바닥에 고정도 아니네대가리가 있으면 저딴걸 설치할리가',
#  '빨개이 새끼들 다 묻어버려야',
#  '1절만해라 짤게에 또 글올리지말고 ㅋㅋㅋ',
#  '저정도 응디는 운동안해도 가능하다 시발 보정레깅스쳐입엇는데 저정도는 다 나와',
#  '결국 남자를 죽게 하는건 뇨쟈들요즘 여자들 순결 지키고 한 남자 한테올인 하는 여자들 잇는지원나잇 하는 세상에 여자들 니들은 남편 이랑할때 아다라시 엿나 ㅋㅋ',
#  '기레기 길다가 돌맞는데 누가 가만히 있냐 쓰레기 어그로꾼 유트브정지당해야지 사회악이다',
#  '좌빨 영화 납시요 개돼지들 선동시키기 딱이요',
#  '조인성 연기 ㅈㄴ 못함 ㅇㅈ',
#  '노령연금 무상진료 혜택보는 개돼지가 세금내는 우리보다 훨씬많아서 글쌔다',
#  '둘다 싸까지없고 둘다 똑같이 보임 바람핀놈이나 혼자당하기 억울하니 세상에 고자질르는 년이나 둘다 똑바로 사세요',
#  '뇌물먹고 자살한 고 노무현 대통령이 분명히 봉하마을 부엉이바위에서 지켜보고 있을 것이다',
#  '왜이리 부들부들거리는거냐 ㅋ ㅋ ㅋ',
#  '애쌔끼 몽타쥐하곤 깝쭞깝쭉 주둥이질하고 자빠졌네 야 이놈아야 이쁜 부선이 망사빤스나 하나 사주고 뻰질이하고 물꽊꽊이놈 끌어내라',
#  '음주운전 시베리안 도그새끼 그리고 아이 엄마는 아이들을 왜 밖에 기다리게 했는지도 이해 안간다',
#  '뭔 핀란드야 ㅆ ㅂ',
#  '장위안한테 카메라 들이대고 물어보면 재밌겠다 만약에 중국 욕하면 장위안도 인체신비전에서 언제나 볼 수 있을텐데 ㅎㅎ',
#  '대깨문들은 국산차지 ㅋ',
#  '스포츠 머리 난이도 존내 높다옆머리 뜨는 것은 다운펌하는게 맞다셀프 컷 하면 뒷머리 좃같다',
#  '오늘도 김치녀 출동',
#  '섹스는 더불어 강간당한테 배워라 그분야 최고 권위자 집단이다 ㅋ',
#  '이휘재 드디어 나갔냐 이휘재 꼴 보기 싫어서 안봤는데 다시 봐야겠네',
#  '학교다닐때 싹수 보이면 쳐맞고 개선되야 하는데 개조옻같은 학생인권 땜시 세상이 개판되고 있다 자유가 남 인권 침해해도 되냐 창작의 자유가 방종이냐 쳐맞을것들 투성이다',
#  '니돈으로 갚아줘 대한민국 세금 남아도냐 미친 포퓰리즘이 나라 말아쳐먹는다 설마 저 말에 또 속으 표주는놈들 없겠지',
#  '고 김주혁님 돌아가셨을때 김주혁님 기사로 인터넷 도배되니까 그 난리치던 엑소의 개집들이었지 아마 ㅋㅋ',
#  '죄없는 공익제보자 테러하면 집회가아니라 폭동일어날줄알아라 군필문베충들아 저게 군대에서 가능한일이냐 감히상상조차 할수없는일인데',
#  '할말이 없노 ㅋㅋ 아이큐 두자릿수 예상한다',
#  '기레기넘 또 나섰네 지금 쓰레기 배추량을 봐라 조금이라도 줄여야 한다 다른 기자들은 이렇게 안썼던데 완전 소비자  마켓팅하는 기업 다 망하는것처럼 썼네 ㅎㅎ',
#  '좆같은 김치년들한테 선택받는게 메리트 있냐 선택해도 거부다',
#  '하여간 흉기 언플 존나함 이제 안먹히지 자국민이 호구도 아니고',
#  '누군지 밝히셈ㅋ 그리고 걘 연예계에서 영구퇴출가자 정유라랑 다를바없잖아ㅋ',
#  '니미 씹이나 차단해라',
#  'ㅇㅇ 동탄아지매 2명이랑 만나봤지 뇌가없는대신 이쁘다',
#  '재앙이 오려나 참 미묘가 시기하네요',
#  '쓰벌 새끼들아 보지마 보면서 왜 작가들에게 상처를 주나',
#  '죽은 세월호 구원파 교주 유병언이 조까사위 딸로환생한듯',
#  '김원희는 왜 애를 않놓노 불임인가',
#  'ㅋㅋ 매갈페미년들 연하남은 커녕 그 성질에 평생 누구하나 사귈수도 없어보이는구만 ㅋㅋ',
#  '친선대사도 중졸에게는 시키지말자',
#  '닥쳐 틀딱련아',
#  '우아 지오누나를 비방하더니 ㅋㅋ 이젠 생시람잡네 보수집권 멸망 아베대변인 주적은 북한이지만 니넨 쪽바리 제일 나쁘다는걸 명심해라',
#  '씨가일단좋아야하고 밭도좋아야한다',
#  '역시 더듬어내로남불새끼들 실망시키지않는구만 ㅋㅋ',
#  '윤서이니야 시시때때로 열폭하는 애라 그렇다지만 여기서 정우성까는 애들은 왜 그럼 유엔난민 홍보대사라서 에 홍보 좀 한거갖고 윤서인 얘도 웃긴게 그러면 지도 평소에 입바른 소리라도 하든가',
#  '개종자들',
#  '빠가야로 안전하게 너희나 이빠이 쳐드세요',
#  '가세연에서 퍼온거 보솤ㅋㅋ가세연 똥은 알지가세연도 아줌마 부대가 점령 했더라김세의가 주예지 팬이라니까 아줌마들 부들부들',
#  '제목 읽기 개힘드네일단 ㅁㅈㅎ줌',
#  '그건 기술자가 아니라 기사다 개병신아 제발 좀 ㅋㅋ',
#  '    빌리좆엘',
#  '각 집단마다 저런 쓰레기들 존나 많음',
#  '누가 악플을 달긴 80년대 최악의세대라불리어는 여자들이지',
#  '빨갱이 새 끼 들',
#  '법부터가 지롤이네 법안 똑바로 안만드냐 국개의원들',
#  '존나 무섭내',
#  '리뷰 이천개 이상 달릴동안 48 유지해봤는데저런새끼들은 히스토리 들어가보면 어떤 가게든지 다 불만 투성이임다 버린데 개 병신같은 새끼 ㅋㅋㅋ병신 보존의 법칙이라 생각한다 물론 대응은 잘 해야지',
#  '백상까지 조작한 문재인들어서고 방송 문화 경제등 비리와 부패가 더 심각하고 망하고있다조작사기댜 비리와 조작으로 인기구걸하는데도 조사없는 문재인끌어내려야지',
#  '개돼지집단 개한민족의 실상 사촌이 땅사면 배아픈 민족이라 앞에선 웃어도 뒤에서 호박씨 까는게 일상임 소름돋는 개한민족 무섭다',
#  '미쳣나 다른사람이 빌린 돈을 왜 내가 낸 세금으로 갚아준다는 거야 ㅁㅊ 개빡치네아주 다 국가세금으로 니들 생색 다내고 저소득계층 사람들만 자기들 빚 갚아준다고 좋아라 하겠네개빡친다고 신발ㅏㅏㅏ',
#  '머찌네년들은 금테 두르고놈들은 노끈이냐이게 진정 니까짓들이 추구하는 평등공정이냐문빠 변신놈년들아',
#  '대깨문들은 죄다 싸그리 한마리도 남김없이 잡아서 똥통에 쳐넣고 농약에프킬라쥐약 락스청산가리술쳐먹고 오바이트 한것살충제유리가루 넣어서 애미추와 국조 인재문 이 잡것들 주둥이에 쳐넣어야 하는디',
#  '알고보니 이 미친놈은 포풀리즘의 대마왕이었네',
#  '기자가 여자네요 화사가 저런 춤 추면 걸크러쉬라고 할거면서 그녀들의 이중성이란',
#  '하늘같은 남편한테 반말하는것만 봐도 구해선이 죽일련이다 남편이 니 몸종이냐 밸아먹을논아',
#  ' 취향이긴한데 가슴은 빵빵해서 좋다 이기',
#  'ㅇㅎ 과거도 현재도 민족의식 애국심 존나 안드는건 마찬가진가지네',
#  '꽁초보다 역겨운 죄인이잠아',
#  '사진땜시 기분 잣같아져서 ㅁㅈㅎ',
#  '스트레스가 원인일듯 문재앙이 책임저라',
#  '실제로 김대중이라고 했는데 김재중이라고 한거라고 구라친거라는 생각은 안해봣노 ',
#  '폐지가 답 전현무 꼴 베기 싫어',
#  '개돼지 대구민들 ㅜㅜ',
#  '네 다음 반일국뽕 폭도',
#  'ㅋㅋㅋ으이그 진짜 정신병자들 많다',
#  '저런 놈년들 안봤으면 한다',
#  '일베좌파임',
#  '다애미뒤진 새끼들이라그래',
#  '이색히들은 코로나종식했다더구만짱개발 인천행 뱅기에 탑승한 짱개가 한국와서 우한폐렴확진받았으니',
#  '마약중독에 성형중독에 휴',
#  ' 이제는 폐업할때  좌빨의 선동만이 남아있는 쓰레기 ',
#  '못생겼으니 옷이라도 뻘겋게 입고 뻘건살 내놔야지 근데 극혐',
#  '지22럴 하네 남자가 봐도 심각 메갈련들이겟지 아님 기생충 박사같은 부류거나',
#  '개소리하면서 도망가지 말고 근거 가져와 씨발 새끼야 ㅋㅋㅎㅋㅋ',
#  '송혜교는 예쁜데 댓글이 너무 인위적이라 보니까 3040대 비율ㅋㅋ역시 나이많은 여자는 나이많은 여자보고 예쁘다 하는구나',
#  '김구라 범죄자 모습같어',
#  '계속 제 잘난 맛에 사니 그렇지 언젠가 크게 걸릴거야 비싼 넌 일반인은 싸구려 기성복으로 보일테지 싼 게 비지떡이예요',
#  'ㄹㅇ 똑같은 업무지시를 해도 사람 진짜 존나 빡치게 만드는 재주가 있음',
#  '에효 니 직장이나 스와프해라 빙시나 쪽팔려 어디 앞으로 글이나 써지겠냐 종양이면 좃선이나 동악일보랑 스와프하면 되겠네 ㅉㅉ',
#  '혜경궁은 그냥 말만함 실천을 안함 언론에 홍보비 주고 언플은 ㅈㄴ함',
#  '연기대상 못타니 연예대상 노리시는 분',
#  '여자 팔자 뒤웅박 팔자',
#  '참고로 여기서 매달리면 조온나 씨발되는거임많은 찐따들이 여기서 멈추질 못하고 존나 들이대다가 이불킥거리를 만드는거다 난 다르다고 생각하지마 열번 찍으면 되는 나무가 아니라 바위산이야얼른 손떼고 딴년한테 들이대라 과거 나에게 외치는 심정이다',
#  '핀란드가 도대체 어디있어 그냥 핀란드풍이라면 핀란드냐 핀란드 스키부대 하강하면서 개머리판으로 이 기자새끼 인중을 치고 싶다',
#  '현실성도 없고 티비 보고 그런 뚱보 짜리몽땅을 보고 농염 하다 생각 할 남자면 지 마누라를 하루밤에 열번 한다',
#  '이국종도 지난번에 욕처먹을짓 했잖아이재명 탄원서 제출한거 ㅋㅋㅋ난 그거 보고 아 저분도 그짝이겠다싶었다',
#  '최정훈도 꼭 퇴출시켜주세요잔나비 잔챙이 보컬 퇴출 운동 시작합시다 ',
#  '저위에 추잡한것 한놈과 한년 사진 내려라',
#  'ㅇㅈㅋㅋ 속으로는 ㅈㄴ게 찔리는일게이들인데',
#  '누군가는 똥을 쳐야하고 내가 치기싫으니까 똥치는 사람 배려해주자 하면 될걸 존나 어렵게 써놓았노 전국의 분뇨관련 종사자들이 들고 일어나면 온국토가 똥바다 되는거지',
#  '당직병을 쑤시면 황희만 바보 되는거 아니냐 열심히 쑤셔라 문슬람 역시 지능이 그 수준이냐',
#  '생긴것도 참 드릅게 생깃네',
#  '문재인대통령님이 계시는 대한민국에 빌붙어 사는걸 축복받은줄알고 살아라  수구꼴통들아 ㅋㅋ 이런다고 공수처설치반대 정권교체가 된다고 보냐 꿈이야 꿈  분수를 알아야쥐감히 어디서 푸하하하',
#  '좌빨 인증하네 ㅉㅉ',
#  '진한 화장 화려한 외모 거부합니다 탈 코르셋 운동 동참하지 않는 모든 여자 연예인들 불매합니다',
#  '악마같은 쥐새끼들',
#  '대한민국은 김치녀들 입김이 너무 세다',
#  '이 무슨 여기가 80년대 초 조선이냐 무슨 말같지도 않은 소릴 하냐 ㅆ ㅂ 같잖아서',
#  '나라가온통 재앙이다 기생충 빨갱이 앵벌이 천국이다 박근혜대통령때는 이정도는 아닌데 한마디로 개판이다',
#  '그러니까 살찐거 컴플이라고 개솔찍찍 하지마 살찐여자들아 키작은거랑 머리빠지는거 노력1도 못하는 그런게 진짜 컴플이지',
#  '정말 거지같은인간들이다 사실을 왜 자꾸 어거지인지피해망상인가 민주당 이것밖엔 안되었나전정부나 현정부나국민들 위하는것들은 없다지네들 권력맛만 알지쓰레기들',
#  '또 중간에 말꼬리 짤라서  무식쟁이들 흥분시킬려고 한다 조센찌라시 마지막수단으로 살아볼려고 고금리에 손을 대는 열시미 살아온 영세민들을 보호해보자는거자나 국가 존재목적이자나공정경제 고 시ㅂㅅ꺄',
#  '맞는말했구만 근데 용접은 뭐 쉬운줄아나 7등급이하 머가리가 용접하면 파이프터져 철아작나고 ㅋㅋㅋ글고 말은똑바로 하자 7등급 이하 머가리가 먼수로 호주가서 영어하냐 바디토킹으로',
#  '잘생긴 육성재 대신 팬들을 위해 니가 군대 두번 가는건 어떻니',
#  '친일앞잡이매국당 놈들이지머',
#  '홍어야',
#  '베충이 시무룩 ㅋㅋ',
#  '아저씨 3명이서 우리 지은이 여기저기 어루만져주겠네 ㄷㄷㄷ',
#  '이 친구 암은다 나앗나 옮으면 큰일인데',
#  '네이버 좆선일 일베 징글징글',
#  '누가보면 셜리가 살해된줄 ㅋㅋ좃무현 자살찬양 좌빨 방송국 수준하곤 ㅋㅋ자살한것들은 욕먹어도 싸다',
#  '쪽바리 고 홈',
#  '도 가능할려나 ㅋㅋ',
#  '의새새끼들 다 기어 쳐나왔네디비자고 새벽같이일어나 일해라 노예놈들아',
#  '오왕 박효신 몇번째 억닥위로 꿀꺽한거에는 반대 이야기도 들어야한다고 해놓고 60만원에는 씹선비 기준 적용하는고 보소 ㅋㅋ 니도 꼭 겪어보길 바람',
#  '그럼 땅에 뭍으라고 뭐 어떻게 하라고저런덴 쓰레기 수거를 안해 병신아',
#  '웹툰 작가들 하나같이 쓰레기집단이냐 ㅡㅡ',
#  '내 글을 유일하게 이해한 새끼가 나타났네',
#  '인사는 무슨 인상만 존나 쓰는데',
#  '안궁금해 뇬ㅇ',
#  '남들 다가는 군대 ㅈㄴ시끄럽네ㅠㅋㅋ',
#  '꽃뱀들 본보기로 처형해라',
#  '미친놈들이네',
#  '이때다 싶어서 편피노들 활개치고 다니네 ㅋㅋ',
#  '남자는 어릴수록 단단하니 맛있음 25살 넘으면 철지난 크리스마스 케잌처럼 흐물거리기 시작',
#  '아주 하다하다 별ㅈ1ㄹ을 다떨고있네',
#  '보지마 조언 필요없어 게세끼들아',
#  '눈 코 입술 가슴 올튜닝 ㅠㅠ',
#  '얘 말하는거 너무 커여웡 입에 내꺼 물리고시펑',
#  '붕신같은 정책들',
#  '머리에 밀웜을 꽂고 다니노',
#  'ㅈ같이 생겼다 진짜',
#  '그래도 삼성 부장 정도면 연봉 몇억씩 받았을텐데 그리고 퇴직금도 오지게 받았을텐데 그거로 차라리 일용잡부 뛰면서 한달에 200정도 생각하고 나머지돈으로 생활비쓰지뭣하러 떡볶이집 오픈해서 고생하시냐 진짜 장사로 투자15억해서 15억 본전만 찾아도 다행인시대다게이들도 만약에 퇴직금 다해서 현찰 2억 정도 있으면 그돈 생활비로 야금야금쓰고 일용잡부 뛰거나 아님 뭐 월급쟁이 마트 직원 그런거라도해라어지간해서 사업하면 돈 까먹고 싹 다 망하는 세상임',
#  '미친',
#  '신호 안받다가 뒤졌음 좋겠냐',
#  '개세이들',
#  '돈많은건 인정하지만 키라도 크던지 김건모와 그어머니는 눈좀낮추셔야 장가갑니다',
#  '찌질이들 보기싫음 안보면 될것을 보면서 찡얼대네 모지리들 ㅋㅋ 왜사냐 모지리들아 ㅋㅋ',
#  '문재앙은 언제죽냐 범죄자ㅅㄲ들이 명줄은길더라',
#  '저게 어떻게 홍콩영화냐 시발ㄴㅋㅋ',
#  '페미 새끼들은 초중고딩이 다 들어다볼수 있는 카페 게시판이나 트위터에다가 아이돌 실명 언급하면서 ㄸㄲ충 만들고 능욕에 능욕에 고문까지 다 시키던데 이게 여혐이라고 하면 진짜 머리빻에 총 맞아야 한다 그런거 봤으면 진작에 남혐이라고 차단했어야 하는거 아닌가ㅋㅋㅋ 여혐이라는 단어를 구사한다는 거 자체가 정신병이다',
#  '페미 망할놈들',
#  '와 시발난 작년에 30됫는데 좆소에서 나랑 1살위 새끼한테 20대초반 후임갈구는거 마냥 진짜 날 모자른새끼처럼 갈궈서 빡치고 퇴사하고 1년가까이 히키생활중인데 시발 니글보니까 진짜 생각할수록 좆같다빡대가리에 남눈치 존나보고 피해의식쩔고 나이는 똥꾸멍으로 보고 사람들은 첫인상부터 날 만만히보고 쉬펄친구도 찐따밖에없도 모쏠아다 일게이라서 씹쫒같노 평생 이렇게 비참하게 살다 뒤지겟다이기',
#  '대깨문 게 3 끼 들 다 뒤 져라',
#  '개 젖같은 상황이 발생하는구나',
#  '나베 미친년 이렇게 욕하시면 안됩니다',
#  '같은 페미년들이 죽인것이지',
#  '화교년이였군 어쩐지 짱깨냄새가나더라',
#  '진짜 ㅋㅋ 댓글 꼬라지 보면 정말 한많은 한민족이 따로 없음 ㅋㅋ',
#  '여성폭력 이란 성별에 기반한 폭력으로 신체적정신적 안녕과 안전할 수 있는 권리 등을 침해하는 행위로서 관계 법률에서 정하는 바에 따른 가정폭력 성폭력 성매매 성희롱 지속적 괴롭힘 행위와 그 밖에 친밀한 관계에 의한 폭력 정보통신망을 이용한 폭력 등을 말한다조문을 왜 니 좇대로 해석함',
#  '햐 시발 욕나오네',
#  '지금은 순 양아치새끼들 영끌해서 지랄같이 운전하드만',
#  '조센진 후쿠시마 수산물 안 사면 국민의힘 동원하여맨날 집회할거다',
#  '계집들은 대체로 이기적이더라',
#  '요즘은 이혼이 아주 벼슬이야 여기 또 이제아마 이상아황은정  이런여자들 나오겠다 남자들 입장에선 이렇게 남탓하는 여자들만피해도 인생 반은 성공이지',
#  '홍어들은 씨를 말려야함',
#  '좆셴 미개한 개돼지들이 원하는거임',
#  '닉갑 오지고 병신색기',
#  '댓글들이 개빻아서 성비를보니 여자 70프로 ㅋㅋㅋ',
#  '문재인아들도 관련있다던데 그래서 그랬나보군',
#  '성형으로 화장으로 속고 자식낳으면 또 통수 ㄷㄷ',
#  '일관성있게 지랄하면 훈장이라도 달아주냐',
#  '랄 하네 보자보자 하니까',
#  '진짜 좆같은 년들만 골라놧네',
#  '근데 개돼지 중 18 이상이 음주운전 경험이 있어서 ㅇㅇ',
#  '기술협력도 해보겠다고 나대다가 미국에게 경고 처먹고 버로우 탔던 게 한국 놈들임',
#  '다들 채식하자 ㅆㅂ 그러면서 고기를 먹는 나는 ㅠㅠ',
#  '기본대출권기본소득세금으로 다펴줄려는 개ㅡㄴ또라이',
#  '빨렙들이 퍼오는 정치글들 제목 보기만 해도 역겨움',
#  '멀봐 이 좀마나 뭐 불만있어',
#  '미투충들아 언론에 놀아나는 개병신들 미투는 니미 좠투다',
#  '짱개말은 다 구라 ㅋㅋ',
#  '우욱 씹 같은 도덕주위자들 누가 유교탈레반국 아니랄까봐',
#  '극단적 선택이 자살만 있는 것더 아니고 개나소나 극단적 선택이래 ㅋㅋ',
#  '저 새끼가 정치에 얼마나 관심이 있겠냐',
#  '지랄을한다',
#  '개코 너도 같은 ㅆㄹ이주제에 아닥해그냥 ㅉㅉ',
#  '쪽바리앞잡이야 너거나라가라 꺼져',
#  '뭔 씹선비의 나라가 되가고있냐 죴같은나라',
#  '요즘개념말아처먹은년들이많아서 여자한테 해주면 젊은자지한테 홀려서 집팔아먹을것같아서 못해주겠음 의외로 미친년들 진짜많다',
#  '대구경북 당선조건  매국노',
#  '얘도 뭐 입으로 훅 가겠네 조만간 넷플릭스 스탠딩 나온다던데 거기서 짤되서 돌아다닐 헛소리 몇개 있으면 그냥 커뮤니티에서 씹히면서 빠빠잉 분위기 나올 듯',
#  '그래바야 오합지졸 가난한 그 지 새 기 들임 덤벼라 깨 문 새기들아',
#  '니애미씨발년',
#  '좌앙의 바이러스 꼴좋다',
#  '아니ㅋㅋ 좀 일반적인 것부터 제대로 만들고 혁신을 노려라 플래그쉽도 개판인데 뭔씹ㅋㅋ',
#  '꼬추 헐겠다',
#  '악플단 인간 말린꼴뚜기같은사람 만나길바란다',
#  '나중에 병원에서 돈 다 쓰고 뒤진다',
#  '악플단다는년삭씨 댓글 연연하지말고 스토리대로 연재해달라는놈 댓글 역겹다는놈 전부 말할것도 없아 ㅄ들이다ㅋㅋ 삭이그리는것도 아니고 불크가 그리는건데 저정도면 그냥 관심도 없고 머가리비우고사는수준이다',
#  '푸하하 고맙다 미친것들아 이렇게라도 웃게 만들어줘서',
#  '전세계 어디도 저렇게 돈 많이 들어가서 적자보는 의료 시스템은 없음고로 이국종 또라이',
#  '쿵쾅이들이 남자 가족 로 로긴 해서 댓글 다냐',
#  '타고난 장사꾼 약쟁이',
#  '근데 그 요구권이 법개정으로인해 경찰들이 맘먹고 뻗대면 안먹히는게 문제다 완전 검찰과 경찰의 수직관계가 이번 검경수사권조정 통과로 인해서 패러다임이 바뀌어버림 시발 검사들 윤석열 욕 엄청많이하겠는데',
#  '너 낚지 모르냐 에구 엠생새끼 라면이나 많이 먹어라 끼니 거르지 말구',
#  '한걸레는 가난한 좃쭝똥일뿐입니다',
#  '저 또라이잘난척 겉멋은에굴 불쌍타구속해서 사형판결내려라',
#  '꼬우면 안보면 되쥬 왜 창작에 ㅆ선비질',
#  '이놈도 위험한 사회주의자구나 종북친중좌빨',
#  '아휴 이런 유치한 스토리를 재밌다고 빨아주는 킴치련 한녀들때문에 대한민국 드라마 발전이 없는거야',
#  '진짜 이세상에서 중딩이 제일 맛있음 갓생리 개통할 시기지 중1이 제일 맛남',
#  '만 들어가면 무조건 다 공식싸이튼줄 착각하는 미드보고 미국배운 조선놈ㅋㅋ 어여가서 단어외워야지 ㅋㅋ',
#  '존나 구라치고앉았노이기야 ㅋㅋ 세월호 타러가라이기야 돈 더많이준다',
#  '잣같은 군대용나온다증말ㅅㅂㅅㅂㅅㅂㅅㅂㅅㅂ잣같은 군바리 새리들전쟁나면 뒤통수 조심해라',
#  '아니라잖아 좀 믿어라 인간들아 싫으면 그냥 니 인생 살고 쫌',
#  '왜 사회 규범 규율 때문에 보지에 피흘리기 시작하면 생리적으로 임신가능 시작을 알리는거 아님 제일 좋을땐데 뭐가 문제야 씨발 개같은년들 애비 등골이나 쳐빨아먹다가 결혼해서 지가 쳐먹고 쳐입던거 씻고 빨고 1인분 할려니 힘들어서 징징대고 우울증 쳐걸리고 개지랄 염병하는 좆쓰레기 헬조센 창년들',
#  '댓글수 보소 학실히 암놈숫놈 짝짓기에 관심도가 존니 높노 천박하고 천한것들',
#  '요즘 드라마 특징 아줌마 용 포르노',
#  '쏭가인이 아내여왜 여기 나오는겨ㅡㅡ이런 글 올려서 난 자동으로 홍자팬 되능겨요즘은 티비돌리믄 라도사투리뿐맘껏 즐겨라들을마 안남았응께ㅍㅎ',
#  '극혐이네 ㅋㅋ',
#  '이제 버러지들 몰려와 신고하여 블라인드 만들겠죠 ㅠ',
#  '문재앙때문에 나라꼴 미쳐돌아가네요 탄핵만이 정답일듯',
#  '현실은 성형한 여자는 차은우는 커녕 김제동도 싫어합니다',
#  '개새끼가 19살 장난하는것도아니구 먹는 음식 가지고 장난좀 하지 말자',
#  '쓰레기같은 쿵쾅ㄴ들 최자탓 기자탓 한남탓하고 있누 ㅡ 지들이 죽였으면서 ㅉㅉ',
#  '세상 살보니 저런 뇬넘들 처음 본다너네 운명도 다 됬다',
#  '기집들도 같이 자놓고 쥐랄하네',
#  '전라남도 안정권 홍어새끼 좆이나 빠는새끼가 가세연을 까노 ㅋㅋ',
#  '재앙이가 위에 나오는 움짤보고',
#  '박원숭이와 그 민주당 여성의원 그 검사뇬 한테는 내편이라 한마디 말도 못하는 족속들이 개소리 까고 자빠졌네 잡소리는 카톡가서 쓰세요',
#  '여자가 감히 욕을 해 좀 맞자 가 정상이라는 한국남자들 역시 그 성별 엄청 감정적이네',
#  '만화를 만화로 보지 못하는 씹선비들',
#  '솔직지 폐미 종나 묻었네',
#  '구라가아니구 그라다 기레가0',
#  '태극기 할배들은 노망나서 그런다고 쳐도 대깨문들은 제정신임 지금',
#  '양기원 웬 듣보잡으로 어그로질이냐',
#  '이거 원글이 의게이가 ㅇㅂ에다 썼다가 각종 커뮤 돌고 돌지 않았냐',
#  '센징들이 이게 문제임ㅋㅋ 몇 살에는 뭐 해야 되고 몇 살에는 돈 벌어야되고 지들끼리 나이라는 낙인을 찍고 남들 눈치보고 삼ㅋㅋ',
#  '결혼했으면 여자가 애를 낳고 대를 이어야지 요즘 여자들은 무슨 생각으로 결혼을 하려는지 모르겠다 남자 등꼴 빼먹을 생각뿐인가',
#  '병신년들 평소 짤게에서 온갖 직업들 조리돌림하던 새끼들이 이제와서 무슨 성인군자라도 납셨냐죠센징 마인드 어쩌구 지랄하기 전에 느그들 자신을 먼저 돌아보는건 어떰ㅉㅉ',
#  '자유지ㅇㅇ남자는 꼭지보이는거 상관없고 여자는 보이면 안되는거임 과하다는건 쿵쾅들이 그러는거겠지',
#  '난 진짜 나이많은 사람이랑은 못 살 것같아아무리 돈많아도',
#  '지디게이 사랑해 일베로 돌아와줘',
#  '저 사람 완치 됐고 문제는 티그가 아닌 씨오투 용접사였는데 마스크 따위 일절 안 쓰고 하다가 저 지경 된거 ㅋㅋㅋ 요즘 마스크 조올라 좋지 짱깨발 문세먼지도 확실히 ㅁㅈㅎ시켜주고',
#  '경단녀가 한다는 게 겨우 출판사에서 연애하기냐 남자 없인 회사 생활이 안 됨',
#  '미친년인데 ㅋㅋ',
#  '일게이들이 제일 좋아하는 소재',
#  '세스코도 졵나 감당안되는곳은 그냥 물건 싹다버리라거나 포기함',
#  'ㅈ 라인이 너무 이쁘다',
#  '저 돌대가리년이 라이트하우스 쳐 보고있는데 말 다했지 뭐',
#  '솔직히 말해서 늙었지 ㅋㅋㅋ 다신 안팔릴 중고를 앞으로 누가 구하겠어',
#  '이런새끼를 좋다고 빠는 문빠와 그교주',
#  '보잘알 ㅇㅈ ㅋ',
#  '사고쳐서낳은애이면서 둘이ㅣ꼴잖내 ㅉㅉ',
#  '덧글들 오지게 잘났네그랴 다들 거룩해서 잘났다그래',
#  '이자식 게이라더니 어디 숨겨놓은 딸이있네',
#  '이게정확한진단이지 하이튼 손뽕들보면 대깨문생각남ㅋㅋ 패죽이고싶음 주제좀알지',
#  '이름이 여자네 생긴것도 기지베 같고',
#  '진짜 애들 볼까무섭다 시발ㅅ아',
#  '솔까 문희준 소율은 너무 안어울림',
#  '스타워즈 클론 전쟁 씨발년아',
#  '더 늙어서 혼자 팍팍 늙어 옆에 돌아봤을때 보살펴 줄 사람 없어봐야 정신차리지 쩝20대 30대도 아니고 쩝 본인 연애니 상관없지만 답답해서 한마디 해봅니다 수고하쇼',
#  '윤아경로당 할매',
#  '부착연결하는 손잡이 추가 구성하면 셀프컷 졸라 쉬워질거다',
#  '아 정말  이쁘고 귀여운애들만 나왔으면 좋겠다 쉰것들 쫌',
#  'ㅇㅂ에선 좌좀분탕이란 오해를 살 수밖에 없음',
#  '술이식기전 ㅂㅅ아',
#  '처량한 종이땍이 놀구 자빠졌네 ㅠㅠ 누가 누구를 테러 한단 말이냐 지랄 떨지마라 ㅠㅠ 세상은 별 사람 다 있듯 일부 누가 그랬넌지 모르지만ㅠㅠㅠ 이렇게 전부를 호도 하는 이런 작태가 ㅠㅠ 선량한 국민에게 너희 종이땍이 들이 테러를 하는거다 지랄 떨지 마라 3류 종이땍이 라도 유지하고 싶으면 ㅋㅋㅠ',
#  '강한나가 훨씬 아깝다 짱께는 잘생겨도 냄새난다',
#  '안전하면 아베하고 스가 니들이나 처먹어라왜 니들은 안처먹고 수입하라 ㅈㄹ이냐 쓰레기만도 못한 것들이구만 방사능 한번 더 맞아서 3번 채워봐야 정신차릴래',
#  '타죽었으면 좋겠다',
#  '깍새들이 시발 존나강요하더라',
#  '내 장담컨데 예전처럼 구타폭행 되면 이새기 벌떡일어나서 날라다닌다',
#  '시계는아침부터똑딱 윤지오같은 애들하고나 어울리는거 보면 원래 개념없는 년인건 확실',
#  'ㄹㅇ 가방에 초코파이 한박스 뜯어서 넣고다니면 그동네 봊이들 다따먹었다얼큰한 소고기국물이 특징인 팔도 도시락사발면이면 모녀덮밥도 쌉가능',
#  '절에서 키우는개 아님티비에나온개 같다 게이야',
#  '그냥 봐라 개새들아 말 드럽게 많네그지새들늬들이 작가하든가아가리들은 존나 털어요ㅉㅉ',
#  '긴또깡 장군님 애인이네 삼둥이 증조할아버지 애인 ㅋㅋㅋ',
#  '누군대 저듣보가',
#  '문재인을죽여야된다 병신',
#  '화사같은 얼굴이 어떻게 아이돌이고 연예인일 수 있지',
#  '틀니대표당으로 바꾸라니깐 ',
#  '성괴티 오지게 나네 씨발ㅋㅋ',
#  '와 진짜 여자생얼 보고 깜짝놀람 요즘 한국여자얼굴은 화장성형은 기본전제를 깔고 만나야함',
#  '전현무조세호 고르라고토 나온다',
#  '백퍼 막장',
#  '전라도 뺴먹지 마라 요즘 좀 안쳐맞더니 간이 커져서 대한민국을 망치려 든다',
#  '어디가나 여자들 치맛바람이 문제야문제 미개인들 ㅉㅉ',
#  '천왕폐하내선일체 조선아 여러 유튜버나 네이버 댓글에서 조선이 2월달에 현씨 실명과 사진을 최초로 올렸다고 하던데 아니면 그들을 고소하던가 사실이면 아닥해라',
#  '찾아본다고 노력한건 좋은데 장묘시설내에서 처리가 끝나면 폐기물이 아닌게 맞음 ㅇㅇ근데 처리를 끝낸게 아니라 화장 후의 부산물을 갖고 나와서 집에 뒀자나그건 폐기물이 맞고그걸 도로 장묘시설에 가져가서 납골당 같은곳에 보관하면 괜찮은데그냥 뒷마당에 뿌렸자나 이건 폐기물 관리법 위반이 맞음 ㅇㅇ멍청한놈 ㅋㅋ',
#  '그냥 너가 못배워 쳐먹어서 해석을 병신같이 한건데',
#  '지랄하고자빠졌네',
#  '용접 타일 도배 이딴게 뭔 기술이야 병신들아머리자르는 깍새도 기술이냐',
#  '그걸 좋다고 추종하는 대깨문 맘카페년들 또한 같은 부류지비정상 족속들이 사라저야 이나라가 세계최강이된다 ',
#  '개나소나 국민청원이야',
#  '대깨문들 거품물고 발악하네 쯧쯧 어서플 중생들',
#  '그래봣자 밤일을 잘해야지 살만뺀다고',
#  '감싸고 지랄이네',
#  ' 요즘 일반인들 섭외 ㅈㄴ하네ㅋㅋ한심',
#  '진짜 우리나라에 불편한사람들 많다 ㅋㅋㅋ 지들 현실에는 평생해도 못버는돈 하루만에 버니까 지들 인생이랑 비교돼서 배아픈거같은데 그냥 니들 인생이나 생각해라 ㅋㅋ 남까면서 자위질그만하고',
#  '그 무슨 바람에서 제사지낸다고 템깔아뒀는데 초보자새끼가오더니 그거 다줏어먹는짤 있는놈있냐 개웃기던데 ㅋㅋ',
#  '전형적인 남자 몸 좋은 거 좋아할 면상성형',
#  '지랄하네 그러케 독재로 우덜란드 빼고는 다 빵에쳐노코선',
#  '성범죄자 이수근은 방송에 나오지마라 아이들이 나오는 프로는 더더욱 나오지마라 아이들에게 성폭행 가르칠거냐',
#  '냅두지 왜 막았어요 그래봤자 한남충 소리들을텐데',
#  '이번 대통령때는 특히나 연예인이 많이 죽는 거같다 재앙이 닥쳤구만',
#  '어딜가나 재앙이 문제야 문제',
#  '어우씾소름',
#  '신고하면 뭐하냐대가리가 빨갱이새낀데',
#  '아빠는 다 암으로 죽는단다',
#  '쳐 자라',
#  '오예 씨발 버닝썬 나도가능하냐 물고빨고맛보고 씨발 ㅋㅋ호족옆에붙어 응디믿고 살아가면되냐',
#  '신경꺼라 개문빠세기들',
#  '암만 페미 욕해봤자 남자가 결혼 원하는 비율이 통계로도 더 높더라 ㅇㅇ 이건 그냥 지들끼리 경쟁하는 거 보고 페미가 몸값 올리니까 욕하는 거 싸게 대주기만 하면 바로 신나서 엥겨붙을 것들이 한남그러면서 상폐녀가 어쩌고 남자는 능력이 있어서 혼자 늙어도 괜찮네 어쩌네 속내는 그냥 눈높이 낮추고 대충 결혼해달라고 바람 잡고 싶은 거고 현실은 능력남은 따로 있고 지들은 여자보다 생활력 없는 천민',
#  '왜 대학 를 하면 안되는지 연예인들이 보여주네 ㅋ 남자는 개인적인 일에 대해서 침묵하고 싶어하지만 여자가 여기저기 떠벌리면서 남자 쓰레기만듬 팩트로 반박하면 잠자리에서 섹드립친거 까지 꺼내가면서 쓰레기만듬 결국 남자 휴학',
#  '일베놈들 헬게이트 열었네 ㅋㅋ',
#  '남자가 딴여자좀 만날수있지 존나 참견질이네',
#  '전 뒤에서 존나 뛰어가 날라차기 하고 도망갈 예정임',
#  'ㅈㅈ위쪽 뼈에닿을때까지 눌러서 재는거라던데',
#  '바이러스 퍼트리기 전에 이미 만들어 놨을텐데 일찍 풀면 의심 받으니 다른 나라도 거의 완성할 시점에 내 놓는거냐 머리 끝까지 사기꾼 시키들',
#  '남의 걸 왜 지좆대로 씨발 어이가 없네저렇게 강제로 무식하게 하면 약만 쳐올리는거고아픈건 본인이 극복해야지 주변에서 염병떤다고 나아지는게 아닌데',
#  '상당히 징그러운 성ㅡㅣ괴세요 ',
#  '7년 휴직했는데 연봉만 따져도 27억임',
#  '작가가 일단 한남 똘 아이 임 ㅋ',
#  '그러니까 표정 관리 좀 하세요',
#  '언제는 사귀는거 아니라며ㅋㅋㅋ 뻔한 거짓말을 왜 하는지 ㅉㅉㅉ 여하튼 남자가 임신공격은 성공했구만',
#  'ㅋㅋ 정존물 ㅋㅋ',
#  '뭐가 감사하냐 꺼져라',
#  '어깨 으쓱하면서 입씰룩이는거 존나 귀엽네 ㅋ',
#  '우리이니정부의 정치풍자는 차마 할수없당께ㅋㅋ',
#  '불쌍한 인간 들 ㅋㅋ',
#  '군대 안간 발치몽 도와준 인성 확인 응 손절',
#  '별 희한한 년이네ㅋ',
#  '임신먼저한게 자랑 더러운짓이지',
#  '그럼 남편이 포주 인건가ㄷㄷㄷ',
#  '정자 제공자가 누군데 그리고 46세에 임신 출산이 가능하냐 ㄷㄷ 근데 46세에도 비쥬얼이 저정도면 나라도 데리고 살수 있을듯',
#  '아니 우리가 임신시켰냐고 애아빠한테나 배려강요하자 좀',
#  '3줄 요약점 설명 앙망 ㅅㅂ3줄 요약점 설명 앙망 ㅅㅂ',
#  '정준영사형시켜라 그리고목매병신',
#  '잉 약쟁이 왜 방송 기웃거리냐',
#  '가 젤 불편해 민노총이 장악한 좌빨 방송 이제 박원숭이 미화한다지',
#  '원래 빨갱이 좌파들은 저런 짓 하는데 애국 우파들은 서재 병신에겐 저런짓 안하지 좀 더티해질 필요도 있지',
#  '이 잣같은 정부는 대체 뭔 짓거리를 하기에 맨날 세금이 모자라냐 도둑놈들이 얼마나 많길래 세금이 이리 모자른거여 ',
#  '도깨비같은 유치한 말장난에 사랑지랄 하는 드라마가 히트하는게 웃겼지 계집들 수준 낮은게 참담하다',
#  '짱깨는 진짜 존나게 졸렬한나라인건 틀림없음',
#  '걍 인실좆 시키시길 금광발견',
#  '죽어라',
#  '좌파는 입만번지르르하구 실상은 빈깡통이라구',
#  '시발 난 이거 안쓰고 떡상할때까지 가지고 있을꺼다 ',
#  '여기서도 쿵쾅 저기서도 쿵광',
#  '문재앙 때문에 애먼 사람이 눈물 흘리네ㅉㅉ',
#  '짱깨방송은 짱깨국에서나 하시길',
#  '이 신발 시키들이   ',
#  '노가다 다니기 싫으면 노력해서 살지 그랬냐 틀딱들아 ㅋㅋ니들 어릴적 꿈이 용접사였냐상황이 ㅎㅌㅊ가 되니까 그나마 할만한 용접이나 한거고 하다보니 돈도 되고 존나 힘든데 보람도 느끼니까 사람된것처럼 느끼나 본데노가다는 노가다임 주제를 알고 살자',
#  '지랄도풍년이다',
#  '넌 시발 뭐하는 새끼인데 여기서 이지랄이냐 기술이나 배워라',
#  '연하남편 빨던 페미들은 답변하라',
#  '염병 추미애땜에 군기강도 무너짐',
#  '장동윤 ㅅㅅ 잘 할 것 같음',
#  '병신동네에서 알바나 하는 주제에 이런글 쓰면 뭐 되는 거 같냐너나 걔네나 똑같이 미개한 놈들이지',
#  '쑤레기들',
#  '그냥 헬쥐팀 처럼 생겼네 이년도 곳 저넘한테 차이고 19년 3월 30일날 혼나 와서 맥주 차마시며 헬쥐 팬들과 유광점퍼 입고 있을ㅋㅋ',
#  '인간쓰레기들의 배설물을 여과없이 내보내는구나',
#  '이런새끼특징 지가 깨끗한줄앎 남들이보기엔 궁상따는씹찐따ㅇㅇ',
#  '남녀바뀌었으면 마스크 쿵쾅이들 떡밥 생겼다면서 우르를르르 몰려오겠짘ㅋㅋㄹㅇ',
#  '대깨삭들아ㅋ 여기서부터 얼타고 있으면 다음주 다다음주어떻게 보려고ㅋ 헬퍼는 홍대 편 이후부터 건너선 안될 강을 건너버린 것이여ㅋ지금 헬퍼를 보고 좉같으면 출구라는 쉬운길이 있다고 쿠왘',
#  '돈이없어서 좋은데 못살지 병신새끼야 ㅋㅋㄱ',
#  '야만국 북한 인간말종국 북한',
#  '누구여 이 개 10 듣보들은 ㅡㅡ',
#  '문재앙이 뭐 덮으려고 연예인 터트리는건지 명백히밝히자',
#  '음주운전 몇번을 해도 버젓이 나오면서 쳐빠개는 광대새끼들이 넘쳐나는게 헬센의 실태',
#  '맞는 말 해도 지랄 시발련들아',
#  '이런데 귀엽냐대한민국 망치는 골빈것들문제인조국이 잘생겼다고 지지하고ㅉ',
#  '쿵쾅이냔들 댓글로 남자인척 하는거 개어이없네 ㅋㅋㅋ 아 물론 니네가 남자처럼 생긴건 맞지만 그래도 남자는 아니야',
#  '수입차 사고 타고 다니자 그래야 현대기아 노조 색히들 일자리 잃는다 툭하면 임금인상 해달라고 분쟁일으키고 헛짓거리하니 이참 안타깝지만 수입차애용해서 현대기아 노조 없애버리자',
#  '어쩌라구 병신아',
#  '거 공짜로 쳐보는새끼들이 말많네걍 쳐봐 병신들아 난 재밌기만 하구만 지들 인생이나 챙기지 작가가 그린 만화 챙기고 있냐 ㅋㅋ',
#  '권태기 온거 맞네  단물 쪽 빨고 버리는듯 주위에 여자가 많다는거지    임  문제는 이런남자를 여자들이 좋아한다는거',
#  'ㅠㅠ 진짜 죽여버리자 저거 미친',
#  '내가 너를 고소하고 싶어 정국아 진짜 존나 패고싶다 생각이없니 국뽕으로 뭘하든 오냐오냐 해주니가 뭐든 니 멋대로 해도 되는것 같아 공항에는 꼬박꼬박 마스크 끼고 오는놈이 놀러다닐땐 마스크도 안쓰고 진짜 서운하다 정국아',
#  '시발 페미년들아 좀 꺼져 댓글창 무거워져',
#  '쪽빠리는 답없음',
#  '고발 씹가능',
#  '근데 실검 1위하던 장성택이 몇시간전에도 순식간에 사라지고 이번에도 사라지네 ㅋㅋㅋ 하여간 조작질 잘해 개  ㅂ ㄹ 들',
#  '허위응모가 만개면 업체 끼면 허위응모가 사라지냐 병신아',
#  '이새끼 백퍼 보배분탕이네 ㅋㅋ 내가 말이 많으면 논리로 반박해 시발년아 어서 좆거렁뱅이새끼가 최저시급타령이여',
#  '김어준이 진짜 사기꾼이지',
#  '얘는 거세가 답이네',
#  '솔직해집시다 남편이 사기친돈으로 살땐 좋았는데 걸려서 빚투 맞을까봐 이혼했다고',
#  '응 정신승리 백날해봐야 용접공들은 신분상승안돼 ㅋㅋ 돈많이버는게 장땡이라고 백날 돈 처벌어봐라 허드렛 좆가다 몸병신되서 만날 수 있는 보지의 카테고리가 어디까지가 한계인지 ㅋㅋ',
#  '설마 1위하겠어 한국에서 불편하게 일본 아이돌이',
#  '소 장 각 이다 부칸도야지 께서 내려주시는 문죄앙의 얼굴에  칠한 사진ㅡ관심 가져주시어 감개무랑하는 문 좌빨ㅡ부칸삐라 구함',
#  '뒈져',
#  '보아하니 줄거리가 노비 유진최가 미국으로건너갔다 성공하여 신분 높은 애기씨 꼬시는 얘기네   의병 애국운동 등은 개나 줘버려  ',
#  '쓰레기 같은 생각을 표현한건 쓰레기지 작품이 아니다그리구 이런 쓰레기웹툰은 18세 이상이라고 해서 세상에 나온다면 코로나같은 세균이랑 다를게 없다언론의 자유글쓰는 자유를 핑계삼아 독을 퍼뜨리는ㅣ퍼뜨리는짓이다',
#  '또라이',
#  '성질드러운깜둥이년나왓네 이년이 성격만좋앗으면 제1의 한현민이엇을건데',
#  '이념 사상 이해는 가 그러나 친문 달창 대깨문 너그는 아니다 오로지 몽둥이가 약이다',
#  '점유이탈물 하나 추가됐군',
#  '게이는 무슨 일하노',
#  '몸주고 맘주고 사랑 주고버림받은 여자 빚이 많아 행복한 여자',
#  '아  죽지말지  쓰레기같은 연예인 많은데 그놈들이 죽어야지  안타깝네요 고인을 명복합니다',
#  '틀니 2주간 압수',
#  '이젠 또 만화가지고 염병떠네 정신나간것들',
#  '시간이 지나 안재현과 구혜선이 이혼한건 잊겠지만  구혜선이라는 여자가 젖꼭지가 못생겼다는 것은 오래오래 기억될것이다',
#  '맨날 새벽 네다섯시에 피시방에 앉아서 노력은 안하고 신세한탄이낭하고있던데',
#  '워낙 개찐따라 현실에선 찍소리도 못하는 설움 인터넷에 몰려와서 쿵쾅거리면서 푸는 피싸개년들',
#  '아니 10년동안 5살인 만화도 있는데 현실성을 따짐 병 신들 이세요',
#  '수달은 조개를 깨먹어여병신들아책 않읽는티를 ㅈㄴ내요부끄러운 줄들 아세요',
#  '아니 뭔 3040대 김치들은 드라마만 쳐보나 ㅋㅋㅋ 아무튼 쓰렉이족속',
#  '야 대깨문 기시끼야 너희들공산주의자 시정잡배 아니짐승들 황희국회의원사퇴하고 광화문에서 석고대죄 하고 병신',
#  '씨이발',
#  '정상이 어딨노 다 본성은 미친 마음이지 근데 깨달은게 본성을 거스르고 반대로 나아가는게 인생인거 같더라 본성대로 살면 좃같아짐 특히 같이 살면 여튼 감사',
#  '헬쥐 모바일은 대갈수장부터 짤라야겠네',
#  '아줌마들 열폭하는거 보소 ㅋㅋㅋ 저 사람들이 당신들한테 피해준거라도 있나요 남의 인생사에 오지랖좀 떨지말고 너나 잘하세요',
#  '이재명은 정신병자',
#  '열폭들하네ㅋㅋㅋ왜부럽냐 나이어린 마누라에 자식들4명에 돈도많겠다 남부러울거없는인생인거같은데 횽님홧팅입니다요',
#  '다른거 다 떠나서 노래가 별로던데 ㅋ아줌씨들은 좋던가 ㅋㅋ',
#  '관종인건 확실함',
#  '아줌마 여자들 드라마충들 강지환이미지 좋으니까 믿기 싫어서 댓글에 뭐 결과가 안나왔으니껓뱀이라는둥 개소리로 베댓 도배',
#  '비위좋노 게이야 취존한다이기',
#  '그만 좀해라 지겹따 아예 남자들다 없애고 구멍들끼리만 사는게 좋을듯',
#  '꼭 그런 거지새끼들이 생명이 돈보다 중요하냐 이지랄하는데',
#  '너가 병신이네 ㅋㅋ',
#  '그래서 승리는청와대랑 연결고리가통 수사가 진행안되네북한대한민국아',
#  '역시 대한민국 여자 답네 남태현이 부실부실해 보이고 의지 약해 보이니 다른 김치남들처럼 몸 부서지게 돈 벌것 같지 않으니 핑계로 뻥 차 버리네 ',
#  '여자들아프로듀스48 보는데 자꾸 초치지마 그리고 관심없음 그냥 댓글을 달지마',
#  '암페타민드립 존나 오랜만이네',
#  '암내치즈누렁내 날꺼같음',
#  '이새리들은 뭘 해도 신뢰가 안가',
#  '표현의자유가 인권보다 위에 있다 페미18년들아',
#  '얼마나 우리나라를 빙신으로 보는지를 알수있내요 역시 인간이하인것들과는 상종을 말아야 한다',
#  '안타깝다 재앙이다 홍은동 극좌동네인데 믿엇던 낮부터 술쳐먹는 대깨문들 득실',
#  '씨발 라이브릭은 광고같은거 없냐',
#  '임신전 손 댔겠지 임신해서는 약 못씀 누가봐도 칼질했는데 무슨 ㅋㅋㅋ 참 뉴스꺼리 없네',
#  '첫짤 저렇게 생긴 일게이들이랑 여태 히히덕 거리고 있었다니ㅜ자괴감 드노',
#  '정말 한심하다 못 살게 구는건 최고네 나쁜새키',
#  '니새끼가 투표한다고 와닿는게 있냐',
#  '니네가 쳐먹어 원숭이 색기들아',
#  '어디서 사회주의 미화질이야 대깨문새끼들은 일베좀 오지마아주속이 답답하다',
#  '저말이 틀렸냐고 대깨문들아 팩트로맞으니 아프니',
#  '소유진은 안끼는곳이 없네 연예계 이장이냐 동서남북 다 싸돌아당기나봐 꼴보기 싫다 넘 나대니까 적당히 나대라 눈꼴시리다',
#  '저번에 국밥집갔는데맛도 씨발 별로면서 존나 씨발 싸가지없길래 사장 보는데서 국밥에 침뱉고 존나 씨발맛없네 하고 나가서 옆집감 ㅋㅋ',
#  '똘아이네 정신감정의뢰바람 소시오패스 나사이코패스 둘중에 하나',
#  '이미 너덜너덜 했겠지',
#  '닭끄네 최초로 탄핵당한 멍청하고 병신같은 개보지',
#  '진짜 조선 페미들은 성평등 외치려면 군대갔다오고 얘기해라',
#  '염정아가 이태란 죽일듯 싶다 ㅠㅠ 이태란 죽이고 저도 죽겠지질투에 화신이니까',
#  '저렇게 어그로 끌어도 구독자는 55만에서 안늘더라',
#  '면상 보고도 니들이 그렇게 말할수 있을까 병신들아 그냥 가만히 쫌 있어라 개 찌질이들아 복귀 안한다는데 왜이리 시끄러',
#  '정보처리기사 들고있는데여기 ㅈㄴ 양심없이 끼어들수가 없는 개씹쓰레기 기사자격증 ㅇㅈ',
#  '역시 고상한척하면서 트위터에 야짤올리는건 뭔가',
#  '조즐 까세요',
#  '황희 게쩌식이 일을 크게 벌렸네 뭉청한 시끼',
#  '거의 또라이수준 표냄새만맡으면일단 지르고본다',
#  '여자도 앞으로 남자들한테 밥 얻어 먹지 마라빈대년들아',
#  '이재명아차라리 더불어더듬당 이념에 맞게일부다처제도 선언해뿌라골빈놈',
#  'ㅇㅈ 한국인이지만 한국놈들 잘해주면 권리로 알거나 이용해먹을려고 한다일 하는거 보면 차라리 탈북민이 의리도 있고 강직함중세시대 스웨덴 용병같다 고용주가 잘해주면 고마워 할 줄 알고 자기 선을 잘 지켜준다 이상있거나 뭐가 지시하지 않은 일 할려면 바로 해야할지 말아야할지 묻고 실행한다그래서 더 호의를 주고 싶음조선족은 그냥 개새끼고',
#  '그 새끼들이 부패하면 누가 견제해',
#  '쿵쾅이들아 니네가 알아야할게 눈코입 윤곽 다해도 겨우중타치든가 다해도 했나싶을정도의 얼굴이 될수도있어 니네들도 알고있어서 안하는거아니냐 해도 크게변화가없을꺼같으니까 그니까 남 비하할시간에 몸매라도 가꾸렴',
#  '제발 부탁인데 외국여자랑 해매력적인 스시녀가 있는데 왜 자꾸 한녀에 빠지냐 한녀들이 스시남 좋아하는거 봤냐 빨리 스시녀 대량 입국 허용해라',
#  '발기부전 냉동자지 에',
#  '여자는 무조건 어려야됨 ㅋㅋ 솔직히 늙은여자는 쓸모가없지 돈많은 소지섭이 17살 연하녀 만나는건 당연한일',
#  '삽자루가 뭔 우파여 또라이인가',
#  '시집 못가는 여자들 어지간히 부러운갑다',
#  '이 인간은 이 인간대로 다뤄라 기안이랑 물타지말고 메갈들아',
#  '사형제도 다양화시키자 짱궈들처럼 교수형말고 사지찢기 포뜨기 산 체로 소각장 넣기 비닐로 말아서 구덩이에 파 묻기 그래야 개퀴벌레 노마스크 난동 테러충들이 짱궈 공산국가 수준이 이거보다 더 살벌 한 줄 믿지',
#  '검색어 조작 하지 마라 지금 코로나 때문에 난리인데 듣도보도 못한 검색어 하여간 이번 정부는 조작 정부',
#  '우ㅡ웩 토나와ㅏㅏㅏ',
#  '겉은젊어보여도속은 늘어졋겟지',
#  '틀무새랑 자한당무새들 싹 사라진 신기한 글이네 ㄷㄷㄷ',
#  '꼬리자르기 지리네연예인놈들 뽕맞은것보다 북한이랑 국개의원놈들 뉴스나 올려라',
#  '와 씨발 진짜',
#  '저거 뭔 뜻이냐 나 이해못하것다 대가리가 끼어서 안 나온다는 거',
#  '학폭 피해자 치고 되게 당차네 심하게 당했다면 보통 저렇게 언플 못할텐데 그냥 갈굼좀 당했는데 잘된거보니까 짜증난듯 결국엔 비슷한 갈굼을 당한분들도 동참할테고 연예인들 긴장좀 타겠네 ㅋ',
#  '왜 내 인생을 여자한테 쪽 빨리고 사냐',
#  '이게 잘사는 동네와 못사는 동네의 차이냐잘사는 동네의 특징이지중졸새끼야',
#  '걍 니뽕끼리 전국체전이나 해라 ㅋㅋ',
#  '시대를 잘못타고 났을뿐이다 보민한국 시대는 다음정권에서 끝난다 그때 당당히 복귀 하면된다 김생민 화이팅',
#  '다음 가봐라 진짜 거기는 종교더라 ㅅㅂ 바로 탈퇴했다 카카오도 곧 탈퇴할거다',
#  '쓰레기통에 쓰레기들이 알아서 모여지니 고마울 따름',
#  '쪽바리들이 건방지게 수입하라 마라야다 쳐먹어라 너네가 제제도 영원히 풀지말고',
#  '애쓴다전파낭비 프로그램 살리자고 윤아까지쓰네아이고 윤아야 세잎크로버 이후 최악의 저 쓰레기 프로그램좀 문닫아라',
#  '쪽바리놈들 이제 팔이 네개 되는거냐',
#  '이 한국의 화이트 컬러라고 깝치는 새기들 속마음을 알수 있었던 계기가 된게 이번 사건임내심 속으로는 다 무시하자나 ㅋㅋ 허드렛일 하는 ㅈ병신들이라고 일베나 지금 타사이트만 봐도 맞는말 했다  그래도 경솔했다 두 의견으로 나뉘는데여기서 맞는말 했다 라고 하는 애들은 그냥 생각이 없거나 솔직한 새기들인거고 그래도 경솔했다 라고 말하는 애들이 그래도 나름 생각있거나 겸손한 애들임요직업의 귀천이 없다고 늘 떠들어 대나 대한민국에선 귀천은 있다 라는 걸 보여준거임 한국의 이중성을 여실히 보여준 경우지 ㅋㅋ직업은 필요성에 의해 생긴다 그리고 귀하고 천한건 판단하는건 본능임 다만 입밖에 꺼내서 일하고 있는 종사자들 엿맥인거랑 속으로만 생각하는건 천지차이임',
#  '이국 말고 러시아에 돌고래 수용소로 이감',
#  '김치녀들은 키 큰 남자만 보면 노릇노릇 좌궁 떨리노',
#  '옆에서 쓴소리하는 사람이 없으니깐 저러지 ㅋㅋ박근혜도 옆에서 쓴소리하면 보지식 기분나빵 하면서 다 쳐내니깐 탄핵당한거고',
#  '미모같은소리하네 미모가 다 얼어죽었다',
#  '방송 이미지는 믿을게못되 며느리 갈굴지 어떻게아냐 김치들아',
#  '경준아 와이프 말 안들으면 좀 패라',
#  '그려 또람뿌와 잘 어울리제 뚱돼지 정으니와 또라이 럼뿌 쑈 쑈 쑈 ',
#  '저년이 누군데 야동배우냐',
#  '귀엽다 ㄹㅇ 감시하네 ㅋㅋ',
#  '청소기 시발 극혐이네 다이슨 미만 전부 짭',
#  '선 즐떡 후 결혼',
#  '야박하고 인색한년들 존나많음 ㅋㅋㅋ 질투심도 강하고',
#  '동안이고 자시고 상관없이 인간들은 어차피8090쳐먹으면 어차피 다 뒤짐',
#  '일마 또라이지 돈으로 감당부터 해 보지',
#  '얜 또 왜설쳐데 조용히 살지 모지란놈',
#  '이거 이자만해도 매년 엄청난 돈이 들어옴',
#  '아니 범죄자를 묘사하는게 뭐가 심각한데 ㅋㅋㅋ 범죄자가 그럼 상냥한 짓거리만 하니 남자가 봐도 심각은 저기 웜퇘지 트페미년들이 지 아비 동생 오빠 계정으로 들어가서 심각하다고 쓴거겠지 ㅉㅉㅉ',
#  '아마추어나 나가는 아시안게임에 프로가 가서 이긴게 무슨 큰 대수라고',
#  '개소리야 니가 빨갱이를 옹호하고 드루킹을 ㅇㅇ짓이라고 말못해서 삐진거야 빨갱아',
#  '결혼사기로 피임안했으니 애생긴거지 아니면 여자가 임신하면 인생망치는데 했겠냐 그래놓고 애죽이라고 하고 양육비 주기싫어 저런건데 피임을하든지 애가지면 책임져라',
#  '애비엑미가 능력이ㅜ되니밀어주지',
#  '대역 없이 유두나오면 영화관 가서 볼게요',
#  '병신이 가치높일시간에 그년 따른남자랑 앙 오빠하면서 질꺽질꺽 하응하응 거린다 뭘 활용할 생각을 하니 ㅋㅋ 세상이 뭐 너에게 진취적으로 나아갈길을제시하는것같음 그거 다 니 착각이다 인생에 규칙은 없다 니가 그렇게 생각하건 말건 니자유임',
#  '정신이 이상한것같애 얘도 애들이랑 친할것같은데',
#  '니네말을 누가 믿냐ㅋㅋ짱깨클라스',
#  '서은수 말고는볼게 없는 드라마정신 나간드라마 보고 흥분하는 조선인 수준은정말',
#  '이제 넌 좃된거임',
#  '헬퍼는 ㄹㅇ정신병 걸린거 같음 시즌1과 너무 달라서 작가 바꼈다는 소리가 괜히 나오는게 아님 아무 연관없는 기안84만 표적되서 때리지 이런놈들은 관심도 없던게 ㄹㅇ개역겹다',
#  '사진에저두년놈 웃는거보면 쌍재수없는데 시브럴',
#  '하도 욕처먹어서 오래 살겠네 그렇게 욕처먹으면서 댓글다는 이유가 뭔가 이게 직업이니 650원 너도 참 애잔하다ㅠㅠ 나이 꽤나 먹었을텐데',
#  '열심히 살자 오십넘어서까지 인간말종쓰레기 소리 안들으려면',
#  '북한남자 10에 9은 동성색스 해봤을거다',
#  '나잇값 못하는 발기부전 땅꼬마',
#  '존나비싸네 어쩌네 투덜대도 결국 너도나도 사재끼죠 ㅋㅋ',
#  '재앙이랑 대깨문들은 대한민국에수 사라져라',
#  '   필요없다',
#  '구하라 싫음',
#  '설리 죽기전에 악플달던 들이 설리 죽고나서 최자한테 악플 달았다더라 거의 병 수준의 들',
#  '얘는 페미예은이 똥차타령했는데 지금 경리랑 연애중이라니 언냐들 당연히 부들부들하지 ㅋㅋ 베댓 인지부조화 꼬라지들 봐라 ㅋㅋ 응 고소장 곧 가니 기다려',
#  'ㅈㄹㅋㅋㅋ 저 기자가 제정신인가ㅋㅋ',
#  '게이야 왜 근거 못 대누',
#  '에이스의 폭행은 리더로써의 마지막 역할이었다 이렇게 동료들을 유명하게 만들어주고 떠난 그의 속깊은 슬픈주먹은 계집들은 이해못하지 ㅉㅉ',
#  '폭설와서 못가도 걸어서 복귀하라는데 저걸 믿는 새끼들 미필 대깨재앙이지',
#  '이 반일국뽕 개색기들은 일본을 배제하고 미국만 따르면 된다는 개소리를 하고 앉아있음',
#  '꼴갑을 떨어요 일반인이냐 장관이냐 육갑까지 던다',
#  '진짜 이인간은 절대 대선에 나오면 안될 사람이네 문재앙보다 더 좌빨이네',
#  '하연수가 아니라 임창정이나 김구라가 저랬어도 문제가 됬을까 젊은 여성들 머리채 좀 그만 잡아라 한녀 살려',
#  '때려죽여도 기러기짓은 하지 말아라 여편내들 외국나가면 100 코쟁이들과 바람남 그거 모르고 니들은 뼈빠지게 돈벌어서 기러기짓하면서 돈 보내주고있지',
#  '걍 해본말인데 또 발기하노 ㄷㄷ',
#  '상놈들 이미 개발해놓고 우한폐렴 전세계에 퍼뜨린게 확실해졌네',
#  '산이도 곧 재기하겠노 응원한다 재기해라 재기',
#  '와이지는 진짜 밥맛이야연습생을 물건취급해',
#  '입장 바꿔서 하등한 너의 얼굴을 니 남편이 못 생겨서 매력이 없다 술이나 해야지 하고 다른 성형 여자라도 좋고 다른 여자들 어장 관리 한다고 생각 해 바라 ',
#  '씨발 존나 이쁘네',
#  '방송출연해서 이런말 막해도 되나 김학래는 가정 없이 혼자사는분인가 글고 아무것도 모르는 우리도 남을 쓰레기라 말할 자격있나 김학래씨도 잘못했다고 인정하는게 좋을듯 어떤 사정이 있었는지는 모르나 잘못한부분은 분명히 있으니',
#  '아가리가 왜저렇냐',
#  '입만 벌리면 구라',
#  '이딴 다큐를 만든 피디나 엄마나 역겹기 그지없다 제발 고인 좀 편히 쉴 수 있게 내버려뒀으면 죽기 전에 악플에 시달리고 죽고 나서도 유출되지 말아야할 문서가 유출되고나 이딴 쓰레기같은 다큐만들면서 끝까지 망자를 모욕하는 개돼지들',
#  '아무리 그래도 그렇치 임마 엄마한데 오나홀 이모티콘을 보내면 어떻하냐 임마',
#  '인간에 탈을 쓴 악마들 이지 이런것들이 사람인가 추미애 조국 그들을 추종하는 무뇌아들 이런 괴물들을 생성시켜 나라를 어지럽히고 국민들을 기만 하는 문재인 아직도 그들에게 진 마음에 빚으로 나라를 개난장판으로 만들것인가 분노하는 민심은 내편이 아니라 아랑곳 없는 거냐  어쩌다 이런것들에게 ㅜ',
#  '법으로 낮술 자체를 못쳐먹게 해야한다 알콜중독자ㅅ끼들 대낮부터 술 쳐먹고 한심하다',
#  'ㅂㅅ이노 ㅋㅋ 수요와 공급',
#  '와 갓새내기 매장 시킬라고 육갑들 떨고있네진짜면 벌 받아야지만 한사람 말만듣고 왜이럼아이돌들도 일진출신 많잖아 걔네들은 전부 감싸고 일반인은 죽이려드네너거 오빠들 부터 매장 시켜라',
#  '조금 너 많이 쳐 늙었어 그리고 신라면 라면 면빨 쳐 먹을때 어금니ㅡ없니 무슨 이빨 다 빠진 노인내처럼 씹어진짜 맛 없게 쳐 먹더라',
#  '거긴 지금 개중공애들도 많고 일단 홍어들이 모조리 이주해온 곳이라 위험해 청소년들도 최악이구',
#  '여자들이 죽인 유니 진짜 한국여자들 설리 구하라도 죽이더니 예쁘고 몸매좋은여자들만보면 못물어뜯어서 안달남 대단해',
#  '어제 직원식당에서 쏘세지 배식 담당인 씬이 존나 웃겼는데 ㅋㅋ',
#  '열애설 부인하면 원나잇한거 들킨거고 열애설 인정하면 사귀는거임 반박하면 연알못',
#  '저런괴물 같은 인간 을더불어 미친당 인간들이 과거 김정은 을 위원장  이라는 호칭 안 부친다고 국회 연설 에서 ㅈ ㄹ 하는 집단이 지금 이나라 집권당',
#  '보집물 맛보고 싶다',
#  '찐따들이 일본가서 살고싶어하는거자나',
#  '미국도 프라임모기지때 휘청했는데 저쌍또라이는',
#  '여자 입은 오랄하라고 있는건디',
#  '가장 좆만한 새끼가 존나게 깝치는 건 세계공통이냐ㅋㅋㅋ',
#  '보기싫으면 안보면 되는거지 굳이 보고와서 몰입이 안된다느니 뭐니ㅋㅋ 그렇게 싫으면 자기가 작가하든가',
#  '으따 박수진 둘째는 배알꼴리고 한채아는 축복ㅋㅋ골때리네',
#  '기사내려라 씹 잘못된 기사를 메인에까지 올린 저의도 무엇',
#  '누구 씨엔블루 사기꾼정용화가 잇는',
#  '대통령이란 새끼가 테러의 심각성을 외면하고 양념 운운하는 친 새끼가 어딨냐  이게 교활하고 사악한 문재앙의 참모습임요 국군통수권자가 국군사기를 심각하게 훼손하는 병역비리에 침묵하는것도 황당하고',
#  '돈 받아 쓰는 쓰레기 기사',
#  '대한민국 악성종양  대깨문 대깨조 대깨추',
#  '장애인 스티븐 호킹박사보다 일베충들의 행복지수가 더 높다',
#  '25겠지 시팔ㅋㅋ',
#  '이 색기들이 병주고 약주나',
#  '늙은이졉이아직빨딱스나',
#  '40살에 폐경에 다리까지 노답이라이 ㅋㅋㅋ',
#  '남이 억울하게 할때마다 에 올리다보면 인생어찌사나 참 아나운서까지 됐다면서 이미지 생각 같은건 안하는구만',
#  '폰팔이랑 노는 니가 ㅂㅅ',
#  '사과 했잖아 그럼 좀 작작하고 그만 해라 성매매충 한남들한텐 관대하면서',
#  '난 이런 연출된 사진은 노꼴이더라 ㅁㅈㅎ',
#  '더럽다',
#  'ㅅㅂ 공산당 정권이네25년을 민주당 뽑았는데 내 도저히 안되겠다 모지리들아',
#  '문재인들어서고 언론이 더더욱 언플날조만일삼고 신뢰잃어 쓰레기되가는즁',
#  '잘주는 애들 남자들 흔한대화 아녀그게 왜 성접대야',
#  '어처구니없는 오보로 밝혀진지가 언제인데 아직도 버젓이 기사 올려놓고있는거봐라 이러니 기레기 소릴듣지  이 기자는 환경부 사무관 에게 기레기 소리 들었다고 환경부장관 사과도 요구하고있다며 뭐 뀐 놈이 되레 성낸다더니 이런식으로 클릭수 장사하면 좋냐',
#  '음주운전으로 사망케 한 사람 사형바로 시켜봐라 음주운전 하는 놈 없을 것임 답을 알지만 못하는 멍청한 사법부와 술먹고 운전하는 저능아 년놈들',
#  '자료 이해 하나도 못하면서 퍼오는건 잘하네ㅁ',
#  '대답이뭐든 그딴거왜봄 이 내 대답이다',
#  '남편이 잘못했지 쟤가 잘못했나웃긴놈들이네 ㅋㅋ',
#  '김제동 까는 넘들 찔리는게 있나벼 인생 똑바로 살면 찔리는일 읍다어린노무 시끼들',
#  '친한 여자사람 친구 신랑이 대깨문이었음친구가 아무리 설득을 해도 한국당 싫다고 못박던 사람이었는데어제 거래처 사장이랑 회식할때 거래처 사장이 문재인 욕을 팩트로 무장해서쏘아부쳤나봄 집에와서는 이제 문재인 정권 지지못하겠다고 얘기했다함 ㅋ',
#  '어찌됐든 변기유천같은 과거 약쟁이 연애인아님 ',
#  '술쳐먹고 운전대를 왜잡는거냐 정신머리 나간것들 에라이 퉤',
#  '기자가 기레기 티내나요 주홍글씨는 불륜녀한테 붙인 낙인인데 책 좀 읽으세요 무식한 기자 양반아',
#  '주식안함 몸갈아서 버는거라 한강은 안감 산재로 뒤질수는 있음',
#  '야동도 야동이지만 게임이나 애니 같은 것도 빠질 수 없음진짜 일본 문화 한국인들 싹 못하게 막으면 다시 하게 해달라고지랄난리부르스 떨듯즐길건 다 즐기면서 일본 ㅈㄴ 욕함 ㅋㅋ 루리웹 뺨치는 이중성임',
#  '페미가 때문에 나라 망한다 병신 오만거 가지고 쌩트집이네',
#  '술을 만취상태까지 처 마시는것도 문제다 취하니깐 자신감 뿜뿜해서 운전대잡지 술 안마시냐고 물어보는 세끼들 다 쳐 죽이고싶다 감빵 쳐넣어놓고 죽ㅇㄹ때까지 술 쳐 맥이면 안되나 그렇게 쳐 마시고 싶으면 지만 쳐 마시든가 왜 다른사람한테 강권해 진심 노이해',
#  '꽃다발사들고 알바하는곳찾아가서 무릎꿇고 내 마음을 받아줄래 지영아 하면 바로 넘어온다 여자들 이런거 존나좋아함',
#  '꼴랑 600만원에 무슨 취업이민 보장한다고 사기를 치노 ㅋㅋ',
#  '아줌마가 노가다하면 남자들한테 존나 따임',
#  '전라도 사투리 듣기싫다',
#  '쿵쾅이들 열폭하는거 보니 웰메이드 드라마가 확실하네',
#  '여성들중에 가장 의욕없고 꿀빨러에 핑계대기 일상인 한국 여자들이 전세계도 아니고  선진국 여자들에 비비면서 임금문제 거론하는게 가장 어이없다',
#  '결혼하기 10증가 ㅋㅋㅋ 그것도 임신도아닌데 정나미 떨어질만하지게다가 상장폐기녀인데',
#  '니가 민폐인걸 지금알앗니',
#  '당직병 현씨왈 나는 미복귀로 인식했다 일개 사병이 왜 미복귀인지를 지가 판단하냐 간부가 할일을 지가 주제넘게 이빨 털다가 죳된거지',
#  '미국 나름 오래 살았는데  근처에 가본적이 없어서 학비가 3500불 하는 학교가 미국에 있는 줄도 몰랐네 ㅅㅂ ㅋㅋ 컴칼다니면서 저러고 있으면 ㅆㅎㅌㅊ 인생인데 ㅋㅋ 그래도 차라리 한국에서 일베나 쳐하는 놈들은 돈이라도 안쓰지',
#  '박근혜 안빠는데 보수통합 3원칙 인정함',
#  '이종석 연기잘하고 존잘 열폭 한남 비율봐라 군대 기사에 발작함',
#  '천연기념물 을처먹냐 잡으면서 먹기전에 물어보는게 기본상식일터 낚시를해도 심지어 금어기인지 잡으면안되는물고기인지 확인하는데 방송하면서 그런거도안지키냐 그냥징역보내라',
#  'ㅋㅋ피로감 지랄 씨발 ㅋㅋ다른 시대에 살다왔냐강점기 시절에 살다온 산송장이면 ㅇㅈ',
#  '자살하는것들은 지밖에 모르는것임그분의마음이어땠나는둥 개소리하지마라',
#  '너희들이나 많이 쳐먹어라 찌질한 원숭이들',
#  '황희 개새  끼에게 손해배상 청구하고 개인정보 유출혐의로 고발해라 ',
#  '기레기들아',
#  '솔직히 울나라에서했으면 개꼴렸을듯',
#  '변기유천  마약범  성범죄자',
#  '앉을대도없는데 임산부석이라도 앉아야지 임산부가 벼슬이냐 다리아파디지겄다',
#  '이런데 중꿔 쪽바리가 따라온다고 ㅋㅋ 쪽바리는  조차없잖아',
#  '그때 조언했으면 멱살부터 잡을놈이ㅋㅋ',
#  '그럼 시발년아 니가 잠수한 곳이 이상한 거지',
#  '세상 살아가는 동안 이런 불륜도 사랑이라고 말하는 짓들 더 보고 싶지 않다 아무튼 쓰레기',
#  'ㅋㅋㅋ 14키로 뺄게 아니라 0하나 더 붙여서 140키로 빼야 하지 않음 보통 저런 몸은 임신도 힘들고임신해도차이가 없어 모르던데출산까지 ㅋㅋㅋ 암튼 행복하게 잘 서시길',
#  '낮에 반주로 술쳐먹는놈들은 대부분 낮술음주운전이 패시브스킬임 단속도 잘 안하는시간이고 대리도 잘안잡히니 그냥 낮술음주운전이 몸에 베어있는 ㅅㄲ들임',
#  '먼가 아쉽다안정환 안닮았어하필 병신 보리문둥이와난 절라쌍도와는 절대 결혼안한다본적까지 따져볼것',
#  '멋을아는게이노 ㅋㅋㅋ',
#  '한국 유명 가수들이 찌질한 동네가서 버스킹하면서 감동 줬다고 자기기만하는 개한심한 프로그램',
#  '방송 못봤는데 김원희 애기 안갖는 이유가 조카라는거조카를 자식처럼 여긴다는건지남편과 시댁 생각은 안하나 남편이 애 못갖는다면 할수없지만 그게 아니면 김원희 너무 이기적인데',
#  '뭐래는 거야 정상혁 메갈 기레기 년이 ㅗㅗㅗ',
#  '짱깨들이 코로나 만들어서 퍼트리고 백신만들어 팔아먹고있네',
#  '말한놈이 쓰래기네 친구가 평생같이살 마누라를 모욕했으니',
#  '정신병자',
#  '김무성이라니까 김무성중국간첩 놈 김무성을 제거 해야지',
#  '걍 조용히 나대지말고 결혼하지노총각 노처녀가 결혼하는게 뭐 자랑이라고건모성격에 굉장한 이벤트를 벌인다면 눈요기감은 될런지쩝',
#  '돈 필요하니 참 부끄럽겠다 쪽 팔리고ㅋ',
#  '그닥짱깨 똥꼬빠는 헬쥐',
#  '곧 남자가 혼자 다 하겠네 ㅉㅉㅉ',
#  '와우 진짜 젖가슴이 크다 가슴이 찢어지면 안돼 돼 돼헉',
#  '도대체가 생각이있는애야뭐야 부끄런지도모르고 아예벗지그래 말쎄다',
#  '니그튼 그지새끼 아니더라도 아 배달비 있네 아 귀찮다 그냥 사먹어야지등등 이런 수요가 있으니까 존재가 하는거고 배달비 받는 업체들이 더 많이 늘어나는 거다거지새끼들아니랄까봐 자본주의시장에서 수요와 공급에 따라서 흘러가는 시장 흐름을 지들 돈 없다고 찡찡거리는 꼬라지 보소 이딴게 일베 ㅋㅋ돈 아까우면 먹지마 가서 포장 해 오던가니들 같은 거지 아니더라도 먹는 사람 널렸어',
#  '여성 혐오는 애초에 없었다 쿵쾅이들 메갈들에 대한 혐오만 있었지',
#  '가장 스레기 ㅡ 설리맘 ㅡ좌파방송 엠비시',
#  '좆병신들 부페 맛없다고 니 애미애비가 해주는밥 인증해서 올리고 그지랄 해라 븅신들아 애미가 밥안차려주면 방구석에서 라면이나 끓이고 있을 새끼들이 아가리는 시발',
#  '잘 몰라서 그러는데 여자들한테 무슨약점을 잡았길래 저지랄을 할수가있는거야',
#  '기사 사진만 봤을땐 그닥 몰겠다 무튼 일본은 짜져라',
#  '니애미 개보지년 ㅋㅋ',
#  '좆무원 새끼들 다 족치고 짤랴야댐',
#  '일베에서 틀딱거리는 새끼들  전라도 대깨문 평균나이 50대이상지들이 노인인 줄 모르고 애들 노는데서 틀틀 거리는 거 존나 웃김ㅋㅋ',
#  '속으론 씹새끼다 생각하는데 겉으로는 그대로 좋은 사람이라고 칭찬하는거지',
#  '좌빨들이 많이들 불편한가 보구나',
#  '대깨문들이 대거 출동해서 베플마다 반대 누르네',
#  '가만히 좀 있지 왜 얘기해서 통까흥 알고리즘 가동했네 씨발',
#  '문죄인이나 잘하라해',
#  '둘 다 타보고 이야기합시다개똥같은소리 하지마시고 ',
#  '다 기관총으로 총살해라',
#  '결제한세끼들도 다 잡아족쳐야지',
#  '예수김정은 ㅈㄴ독재자새끼',
#  '소위 대깨문이란 애들아 젊은나이이 벌써 정신줄 놓고 남들따라 똥파리같이 존심도 없으면 어쩌냐 쩌그들이냐',
#  '엘쥐 직원 이게 혁신입니다  스티븐잡스 야이 ㅅ 부랄 탱탠부랄',
#  '미 친 샛 기들',
#  '페북에 떠도는 유머글 ㅁㅈㅎ ㅡㅗ',
#  '당시 김학래 유부남 아니었나 그렇게 기억하고 있는데 그럼 첩이지 병신이 방송에 나오고 역겹다',
#  '이 새기는 참 경제개념이라고는 1도 없는 무슨 초딩이냐 철없는 애새기마냥 조르면 다 사주는줄 아네 말만 하면 돈이 샘물처럼 솟아나오냐 요즘 초딩도 지 집안형편은 알아서 너처럼 안해 등시나',
#  '존나 띨띨해보이노',
#  '독보적인 쓰레기 방송국이네 가지가지한다경연프로그램에서 배출하고 돈 뺏어가는 방송국 첨보네',
#  '미친 쪽바리 새끼들',
#  '주말드라마는 할줌마들 전용이라 어쩔수가없음',
#  '딸들이 아버지가 햇던 발언을 알려나 ㅎ 돈주고 성매매 인터뷰',
#  '기더기가 병신천지ㅋㅋ',
#  '한남이 또 살인했네 ㅉㅉ',
#  '지랄도 풍년이구만',
#  '아가리 똥내로 객사할 듯',
#  '복귀해야되는데 집이없어서 걍 자살함',
#  '확실히 여자는 나이먹으면 가치가 훅훅 떨어진다 대부분 나이먹은 여자 연예인은 젊을때 잘나가던때에 비해 객관적지표들이 소박해보이는 신랑감이랑 결혼 하더라',
#  '영감 이라고 부를 나이에 왠 부끄럼둘 다 곧 환갑아님',
#  '나쁜넘의 색기 퉤  느그자식 처 애미애비도 제발 불운과 저주가함께하길빈다',
#  '발기부전어떻게고치냐',
#  '음주운전목구녕아가리찢어야',
#  '악플러들은 잡아 족쳐야 되지만 실명제 실명제가 뜻하는게 뭔지나 알고 말하는건가  여기가 중국이야 북한이야',
#  '한국년들 지들 수준은 생각치도 않고 가관이네 니네 비위 다 맞춰주면서 살려면 나이차가 최소 20년은 나야 맞춰주지 돈 잘버는 남편 만났으면 고마운줄 알아야지 하나 채워지면 하나 더 내놓으라는 심뽀 징글징글하네',
#  '저런 친 인간을 봤나 왜 내가 낸 세금으로 남 빚을 갚아야 하는겨  상 똘 ',
#  '구민들이 합심으로 순국선열 엿 먹이는 동네요',
#  '아줌마 ㅋ 어캐 됨 ㅋㅋㅋ 아직 이야 ㅋㅋ 또 빤스런  ㅋㅋ',
#  '진짜 죽여버리고싶다',
#  '퇴물아재 결혼 얘기말고 우리 방탄 오라버니들 미국 프로그램 스케쥴 잡혔던데 그거나 기사내주세요 기자님',
#  '어디 가둬놓고 불태워죽여버렀음',
#  '저거 딱봐도찐따새끼가 일진형님 휴대폰번호로 장난치는거같은데ㅋㅋ',
#  'ㅂㅅㅅㄲ 용접이 뭐가 어때서 ㅉㅉ 정신과다녀라',
#  '요즘 남자들 너무 불쌍해돈 있어도 애첩질도 제대루 못하구',
#  '밤마다 어지간히작살내나보다 살빠지는 거 보니 ㅋ',
#  '유상철은 왜 안죽지죽을때 됐는데 너무 조용함',
#  '진짜 기레기새기가 처돌았네 그럼 영화 드라마는 왜 딴지 안거냐 이새기들이',
#  '추석지나고 확산 겁나되면 누가 책임질래ㅂㅅ가튼 정부 시키들아 그냥 25단계를 놔두란 말야굴머 죽는게 낫지 코로나걸려 디지는게 낫냐진짜 뭐하는 짓인지',
#  '철대패로 저놈들 흑두 네알 싺싹 밀어서모래밭에 파묻고 싶다가능하다면 동작동가서 두개골도 빠사버리고 싶음',
#  '찐한테 감정이입하는 찐들짠하다 ㅋㅋ',
#  '대한민국 금메달리스트가 꼭 이 시국에 쪽ㅂㄹ랑 결혼까지 해야 속이 후련햇냐ㅕㅑㅑ',
#  '기술쪽은 공부 안하는 줄 아나보네 ㅉㅉ설마 기술 배우는거랑 단순 공장 조립 노가다랑 같다고 보는 건 아니지',
#  '강사도 누구나 함 주둥이만있으면',
#  '아 진짜 개새들 뒤통수 졸라 쌔게 까고싶다ㅅㅂ',
#  '대깨문이란자들은 우도며리몇명이선동질하면 대가리에똥만들어간것들이 개나발부는거니 신경씢마십시요 황희등정치인과 저들의지도부 또 대깨문들 싸그리고소하에주십시요',
#  '개좆평타치',
#  '저 가운데 앉은분이 말하길 여자 질크기는 입크기와 비례한다 하였음 즉 입작은 여자만나라',
#  '둘다 해당되는거지 지금의 신생아들이 30년 정도뒤에 현 340대 틀딱이된 정년퇴임자들의 연기금을 매꿔줘야하는데 인구절벽 때문에 그럴 가능성이 거의 없고 그거에 맞춰 법 개정이 될거야 이대로 가면 답이 없음지금부터 아끼지 않으면 시간이 흐리면 흐를수록 더 좆됨',
#  '난 취중 고백 이런거 존나 이해안감 술취해도 난 어느정도 뇌는 컨트롤 되던데몸은 안따라줘도',
#  '그래서 이 와중에도 박한별을 욕한다는게ㅋㅋ역시 대단한 나라야',
#  '니가 이야기 하는 막강의 근거는 뭔데 ㅋㅋ원하면 사람 세울 수 있고 협조 안하면 공집방으로 막강하게 제지할 수는 있지만 그거 걍 귀찮아서 안하는 거임  이게 무슨 개소리지',
#  '수조원 이지랄났네 미친새끼 ㅋㅋ 이건희 재산이 19조인데 수조원 정신나갔냐 ㅋㅋㅋ',
#  '일베놈들 이참에 박멸가즈아',
#  '김선교 저 얼간이는 이제 팽당했으니 막가자는거지 아 한씨였구나 관심이 없어서',
#  '이런 놈 추종하는 거 보면 ㅃㄱ이들은 전두엽이 사상에 잠식돼서 이성적인 사고를 못함 질떨어져',
#  '계집들은 여름에 브라자 대신에 꼭지만 가리는 접착식 테이프 붙이지 않나',
#  '언제부터 맹세한다는 의미가 약속한다는 의미와 동일시 됐냐ㅋㅋ 지랄났다 진짴ㅋㅋㅈ 달렸다고 한 마음으로 쉴드 쳐주는 것 봐라ㅋ 어이가 없네ㅋㅋ',
#  '올해 안에 꼭 자살해라 존못새끼야 ㅋㅋ',
#  '아니그럼 팬티를안입은거야헐더러워',
#  '고현정 배되지가 불러서 그런행동 하는거지돈이 아쉬워서 하는것도 아니니 지맘에 안들면 무뢰한짓 하는거지 뭐가끔 얼굴 까먹을까 드라마 뜨문뜨문 등장하고그냥 접고 동남아나가서 살아라 얼굴도 못생긴게 지꾸 방송탈라고하네',
#  '아 좌파정부 새끼들가지가지한다',
#  '여기서 민주당 중진까지 연결되고 그다음 임종석 문재앙까지 연결되서 탄핵이 시작되면 정말 좋겠습니다 막장 대통령 탄핵이 제 소망이자 희망입니다',
#  '내가봤을땐 작업당한거 같은대 카지노 자체는 불법이 아니였겠지만 슈가뻔히 돈잃을꺼알고 옆에서 똥꼬간질간질해서 돈빌리게하고 돈빌린곳에서 뽀찌때주고 했을꺼같은대',
#  '나도 존나맛없어서 다 버리고 햄버거 시킨거 리뷰 올린적 있는데 내꺼 찾아서 보내도 레전드겠노ㅋㅋ씨발 맛없는 음식점은 다 장사접고 나가 죽어야함',
#  '에이 추한년',
#  '이런 개부럴같은 시끼들은 세금많이 내는 국민들을 적폐취급하며서 개호구로 보는겨 왜 니들같은 말도안되는 개돼지들이 내세금으로 니들꼴리는대로 하는겨',
#  '좆 잡고 있었노',
#  '그 조사하던 경찰한태 따지든가 막가파는 뒤질때까지 막나갔는데',
#  '여자에 매력은 긴 다리와 아담한 엉덩이 그리고 큰 가슴에서 나온다 ㅋ 이효리는 얼굴 외에는 여러모로 아쉽다',
#  '미통닭놈들 태극기부대새끼들 후쿠시마 수산물에 우너전오염수 쳐먹이자',
#  '대한민국 젊은배우는 다 죽었냐 공효진이 언제까지 연애 영화에 나올꺼야 60먹고도 나오나',
#  '페미년들이 죽인거지 누가 죽여 ㅋㅋ 찾아가서 댓글로 괴롭힌 사람들이 누군데',
#  '어쩌라고 퇴물틀딱이 이사를가든 뭘하든',
#  '공놀이나 쳐하는게 뭐 벼슬이라고 ㅋㅋ 김치남 한남들 못생겼으니깐 즈그들끼리 빨아대는거보소 ㅋㅋ',
#  '그런 한남들이랑은 근본부터가 다름',
#  '하나부터 열까지 전부 가식으로 보여짐 ㅋ 내가볼땐 얘네들 이 프로그램 끝나면 절대 안볼 사이들이야 옥주현봐라 프로그램때문에 억지로 어울리는거 한눈에 다보임',
#  '음 근데 일게이들은 관계없자나 결혼 안할거자나',
#  '계집들댓글보소 누가 아깝니 그런 개소리는 여자들 왜 하는겨 여자종특인가',
#  '대구경북포항은 일베틀딱병신들만 있어서 당선됨',
#  '패미냔들을 욕하는거지 정상적인 여자들 욕 하고 혐오 하는 남자는 거의 없다 ㅇㅋ',
#  '걍 한국인 특징임 잘못된거만 알려주면되는데 꼽주고 갈구는거 글쓴이 미필이냐',
#  '실업급여 허위로 타먹은적 있는 새끼들은 돌 던질 자격없음',
#  '다음 생에는 갓남으로 태어나라 갓남 찐 장애인으로',
#  '기사 하단의 좋아요 싫어요 슬퍼요는 의미없지않냐존나게 슬프고 가슴아픈 기사의 내용이지만 이 기사를 메인으로 올리고싶다고 판단하는 새끼들은 그 슬픈기사에 좋아요를 누를테니ㅄ같이 기사 하단 조아요시러요 같은 논리는 적지말자',
#  '나중에 바이브레이터 사서 보지에 지이이잉 할듯',
#  '이새끼 나이도 존나 마니 처먹은 들딱이더만',
#  '순하고 착하면 남자는 등쳐먹히고 여자는 걸레되기 딱 좋은 듯',
#  '개독아 배워라',
#  '대깨문들은 정신병자 수준이다',
#  '딱 보면 모르나 누가 더 문죄앙스러운지 사기꾼박인지',
#  'ㅅㅂ 이게 나라냐',
#  '여대생 냉찌꺼기 빨아먹고싶다',
#  '무현이는 인권없는겨',
#  '무게치는거에 인생버린새끼들',
#  '정은이한테 꿈깨라고 전해라 ㅋㅋ 그럴일없다미국이 미쳤다고 우리 받아주노',
#  '개랑 고양이에 환장한 애들치고 정상인 애들이 없음',
#  '어뜨케법만으로 절대해선안돼살인자 새기',
#  '아니 노예 해방시켜준 일본한테 고마운거면 니들이 일본국민이 될 기회를 박탈해버린 미국은 왜 빠는거냐고 ㅋㅋㅋ',
#  '업소 여자라며 업소여자는 뭐하는 사람인데 ㅋ 그리고 왜 변호사가 하필 강용석인데 ㅋ',
#  '집값 올라간다는 놈들 근거도 없이 그냥 입터는거지 그걸 믿냐 사기꾼 새끼들인데 참 나ㅋㅋ',
#  '한남들 데이트폭력 근절해주세요 특히 애인 아내 죽이는 한남에게 사형을 주세요 그리고 가정 폭력범은 신상을 공개해주세요',
#  '공산주의도 아니지 그냥 망상이지이상 선동할때다 같이 잘 먹고 잘 살자현실다 같이 평등하게 대가리 깨지자 기득권 소수 제외예 중국 북한',
#  '한지민은 그렇게 이쁜얼굴은아닌거같은데',
#  '개새끼들이 뭐만 하면 지랄이야 작가가 니들까지 맞춰줘야되나',
#  '어디서 이래라저래라 명령질이야 씨발년아 좆까',
#  '조만간에 이 부부도 이혼각이네 ㅋㅋㅋ',
#  '근데 진짜 자살할생각이고 자살한 사람보면 자살을 암시하는 어떤 행동도 안하고 진짜 가던데꼭 힘들다고 자살에 실패하는 사람들이 대부분 저렇게 티내고 시도하고 안죽던데',
#  '살찐돼지들 진짜싫다 남녀노소 돼지들은 개극혐',
#  '남자만 조사하지 말고 여자도 물이 얼마나 나왔는지 조사해라 물이 많이 나오면 흥분한거고 그건 동의한거다',
#  '여자들한테 엄청 밉보여서그런듯사실 장신영은 엄청 응원 해놓고 정겨운은 왜 욕하고지들 맘에 안들면 버렇지이프로 주시청층이 통계나오지ㅋㄴ',
#  '내가 최지우남편이면첫날밤 일곱번 가능합니다',
#  '어휴 조선 새끼들은 그저 꼬투리 잡는건 기집이나 사내 새끼들이나 똑같다 왠만하면 하는게 용접이니 비유를 한거 가지고 아직도 이지랄들을 하고 자빠졌네',
#  '전주 절라녀 악플로 엄마가 그렇게 되었으니 모든 절라인은 너의 원수다옛고서 옛어른들이 멀리하라는것은 다 이유가 있다',
#  '김밥은 어느 나라 음식이노 ㅋㅋ 이 씹새끼야 ㅋㅋ',
#  '느금마개보지',
#  '키작고 못생겨도 연예인만하면 나이어리고 이쁜 여자들 줄줄 따라다닌다 그리구 같잖은 사업도하고 ㅋ',
#  '똘아이 추자현이네 남자 잡는여자네',
#  '댓글 보고 상처 안받았으면 좋겠네요 우리나라 사람들 속에 화가 많아서 그저 화풀이 하는거임 ㅇㅇ 어떻게 보면 불쌍한 사람들',
#  '현아 응원하는 애들 도대체 뇌가 있는건지 회사에 피해끼치고 튀는 것 그 이상 그이하도 아님 그냥 해고각 위자료도 받아야 할 판',
#  '쪽빠리 새 끼들 양 아치짓 늘그래왔듯 느그들 끼리나 다 쳐 드시길',
#  '니들 재미없으면 쳐 보지말아라 조오온나 재밌고만 조오올라 지이라알 떨고 자빠졌네 다음주에 또 보러올꺼면서ㅋㅋ',
#  '상수형님 성공 케이스지 시발나마 부럽다고 해라 걍',
#  '아니 김씨도 그냥 컨셉이지 실제 산업역군이라고 생각하는 병신이 어딨냐일하러 갈때마다 인간 쓰레기 취급 받고 구석자리 아무대나 오줌싸고 함바집에서 거지같은 밥이나 먹고나서 햇볕잘드는곳에 앉아있으면 머리가 멍해지는게 매일 매일 일상인데',
#  '아니 진짜 김혜나 너무 싫음 오죽하면 꿈에도 나옴',
#  '이런 개소리하러 오겠죠',
#  '결국 구걸해서 앨범냈다는 소리네',
#  '여자가 99억명이면 좋겠다 그럼 결혼하기 쉬울텐데 골라먹을수 있으니',
#  '역시 김정은이다 대단하다 인육을 처먹는 중국 스벌 인간들이나 고모부를 쳐죽이는 김정은이나 어차피 악마이며 세계의 인류의 적이다 중국이나 빨리 붕괴되라 더러운 짱꼴라 아중국녀ㄴ놈들 니네 나라 망하고 한국으로 절대 오지마라 냄새난다 에이 퇘 퇘 퇘',
#  '헬스장도 떳다방임 오픈빨일때 팔거나 못팔면 잠적 이런새끼들 좆나게 많음',
#  '그냥 니가 개소리하니까 나도 개소리한번해봤다고하면되자나',
#  '박해미정도 글래머면 이혼하고 재결합까지도 얼마안걸릴듯 아직도섹시해서 돈있는영감님들사이에선 최고의인기녀지',
#  '저걸 히죽거리며 얘기하노 씨발새끼',
#  '노무현 하지 않은게 다행이네요',
#  '웬지 페미에 문슬람 같노 ㅋㅋㅋ',
#  '고종이면 모를까 지랄을 한다',
#  '3시리즈는 70이랑 비교해야지 어디서 아반때를 쳐올리노',
#  '얼굴 못생긴 오크들 또 댓글에서 열폭하네',
#  '그건 니가 개보지년이어서 그런거 아닐까',
#  '갑상선항진증이라 눈튀어나온거 고쳐진거라 하잖아요 그병이 얼굴고 붓고 그랬을텐데 다 빠진걸테고  눈들어가는 성형도 있소',
#  '젊음을 위한 주사맞고 수십억을 쓰던그리고 감옥가있는 누군가와 오버랩',
#  '소추 한남 챙롬들 부러워죽겠나봐 ㅋ 느개비 밥이나 차려라 느개비 굶어돌아가시겠다',
#  '남 앰 타령하기전에 니 애미나 신경 좀 써라',
#  '그만 좀 해라지겹다 이제',
#  '좆급식부터 철딱서니 없는 20대 초반 여자들이',
#  '다 아티스트인 척 연기하는겨 6개월 작업하고 6주 활동하고 6년 먹고 사는데 오지랖이든 뭐든 그만해',
#  '응 학폭레기 감성팔이 집어쳐',
#  '아니 진짜 솔직히 말해봐 너 지적 장애있지 ㅋㅋ',
#  '오늘아침에도 뉴스댓글보니까 매크로 오지게 돌아가더만 팀이몇개나있을지모른다',
#  '미친 조선족아나 럼청 좋어허겠네',
#  '이제 알았냐 빠른 이민만이 답이다애국 좆까라 그래라',
#  '이모현 이런 사항을 예상 못 했다고 ㅅㅂ  이제는 하다하다 이런 개같은프로로 이슈 만드네 지랄을 하네',
#  '이런글쓰는애들 특징 키만큰 씹여드름안경충 대두열폭들 키작은존잘남보면 내보다작내하면서 어깨힘드감 현실은 ',
#  '그럴줄알았다군대에서 다친거냐가기전에 다친거냐어차피 훈련소만 갈꺼였네계산된거지뭐누가보면 국대 금메달리스트인줄',
#  '저 정도면 취미로하는 새끼인듯',
#  '놀고잇네 ㅋㅋ 연기연습이나해라 ㅋㅋㅋ 지가무슨 맨날 예능만 찍어싸고이쁘가이쁘다 하니까 신났네',
#  '송혜교가 훨씬 아까웠음 화이팅',
#  '효린아 이쁘고 잘나가는 니가 참아라 저런 면상도 못 까서 뒤에서 징징대는 쿵 쾅이들 뭐할려고 상대하냐 인생패배자들 지금와서 삥뜯어볼려고 에라이 캬악퉤슈',
#  '넌 면상을 들이댄게 죄여남친이랑 그란짓꺼리하고 다시 얼굴 내미는게 죄지반성하는척 하는것도 죄지너도 정준영꼴 날듯',
#  '생생 할때 도경완은 왜 후배 조충현 아나가 말하면 안웃고 반응안해주죠 꼰대 선배의 표본한국인의 표준상',
#  '한남들아 제발 악플좀 멈춰 왜 바닥을 자꾸 찍냐',
#  '이쁜 김치녀인거 빼고는 상대가 안됨 ㅋㅋ현우진 저사람 스탠퍼드 수학과 ㅋㅋ',
#  '국산차 안사는 이유  수출용처럼만 만들라고 10년넘게 안들리냐 그리고 급발진 언제 인정하고 개선할래 아무리 외관 이뻐져도 대가리 텅텅 마음 쓰레기 ㅇㅈ',
#  '저거 에비없다고 국장되는거 아님어느정도 성적도 맞춰야한다대가리딸리는 일게이들은 어차피 못받으니부러워할 것 없음',
#  '페미년들 이악물고 진화 소원커플은 멋져요 이뻐요 하고 젊고 이쁜여자가 나이많은 남자만나면 욕하기바쁘니 즈그 손가락으로 사람죽여놓고도 최자탓으로 물타기하네소름돋는다 진짜',
#  '환경점검 공무원들이 다 그렇지 뭐ㅋㅋㅋ경찰들도 업소삥뜯는게 일상',
#  'ㅋㅋㅋ 41살에20살이랑결혼한다데니 김새론영입하누 영계킬러ㅋㅋㅋ 사촌형 ㅇㅈㄹㅋㅋ후전드냐ㅋㅋ',
#  '이시키 존놔 위험한 섹히여 진짜 자꾸 뭘 국가가 한댜 그냥 적당히 월급이나 받고 짜지라 자꾸 뭔가하고 개입하고 공산주의놀이하니까 다 어긋나는거아녀',
#  '둘이 좋다는데 페미년들 쿵쾅쿵쾅 한심해',
#  '다른건모르겟고재미가없다 이상민얼굴에 웃음기도없고 멍때리거나 크라잉랩이나하지',
#  '트와이스 투어 세명 빼고 립씽 한다고 현지에서 조롱거리라며',
#  'ㅋㅋ 문재앙 이제 하다하다 박명수 한테도 욕먹네 ㅋㅋㅋ',
#  '그런말 하는 너도 결국 당해보면 그딴소리 하지도 못할걸',
#  '관심없다 문씨아저씨 일자리 언제 없지는가가 관심이다',
#  '늙탱이 40대 줌들이 빠는 그새끼네 ',
#  '여자들이 드라마 보고 평가하는 기준  오로지 남주가 잘생겼냐에만 생오줌 질질싸면서 초점이 맞추어져 있지',
#  '재밌는데 왜 10 ㅈ1랄들이여',
#  '미친 내도 여자연예인 하고 함 해보자 나도 방송출연해줘 장동건보다 잘생겼다고 자부한다',
#  '뇌가 없나',
#  '못사는놈들은 원래 염치라는게 없음그래서 더 못사는거고길같은데 아무데나 가래침뱉고 오줌싸고 공공질서같은거 하나도 안지키면서 정작 본인들 손해난다 싶으면 바로 피해자코스프레함',
#  '돼지뱐태 천생 아줌마 지 어미 닮아 돼지년이지 뭐',
#  '아휴 방구석 딸중독 새끼 마 거 매직데이 온거데이',
#  '코재 꼰대섺꺄 55살 밖에 안처묵고 반말 찍찍하고 ㅉㅉ 뭉쳐야산다 덕에 방송가 기웃거리다 훅간다 예의없는 음주운전 5회이상한 쑤랙이ㅉㅉ',
#  '안산다는데 와저ㅈㄹ인동',
#  '왜 욕먹는거연예인들 몰래 사귀는거그럼 욕 안먹을 연예인이 있긴 한가또 머 있음예능 찍은거무슨 다큐 찍었나이상한 인간들이네 욕먹을 이유가 1도 없는 연예인 같은대 쓸때없이 ㅈㄹ들이네',
#  '아놔 이 또라이들 긴머리에 왼쪽볼에 점 있고 이쁘면 다 아이유냐 우길껄 우겨야지 아예 웹툰을 보지 말던가 지들이 실컷보더니 단지 맘에 안들면 여성혐오 얘기만하고 왜 남자혐오는 없냐',
#  '같은 자국민이 아니니까 좆도 하루한끼 먹이고 하루종일 일시키고 개구리에 돌멩이 던지듯 쌍놈들 대가리에 돌던지고 여종들 돌림빵해도 양심의 가책을 받지않을수있는거임',
#  '자랑스런 대한민국을 문재인 정권은 패거리 패악질 정치양심부끄러움두꺼운 낮짝으로 이렇게 망가 뜨릴수가  조구기의 정의저썅앙년의 두꺼운 낮짝이정권의 패거리 두목인 문재인에게 묻습니다니들 패거리 데리고 산속이나 들가라정권교체',
#  '재앙이 이놈이 끊임없이 재앙을 낳는구나 쓰레기 열등덩어리 시퀴',
#  'ㅋㅋ1500만원 이지랄',
#  '애들아 진지하게 질문하나 하자내가 고기를 존나게 좋아한다 특히 돼지고기삼겹살을 진짜 삼시세끼 매일 먹고 싶은데 정육점이나 고기집하면 고기 매일 먹을수 있냐 진짜 진지함 정육점이나 고기집 들어가서 직원으로 일하면 매일 고기 먹냐 고기 먹는 직업좀 알려줘라 나 그러면 평생 일할수 있음 돈 많이 벌어서 그돈으로 고기 많이 사먹으란 개씹소리는 하지말고 ',
#  '끝난건아는데 다시보고또보고 이지랄하길래요',
#  '십세 얼마나 해먹은거야해먹은돈딱50배만 벌금부과하자망하지는 않겠지 망하면 더 좋고',
#  '군복입고나오면 적폐아녀 문재인이좋아하는 인민복에 인공기달고나오면 쭉쭉올라갈텐데ㅋㅋ',
#  '시발 이게 뭐야',
#  '응 니네가왜열폭함 니네는 여자로01도안보일텐데 관계없는얘기임',
#  '조선 수준나옴 힘들게 일하면 대우받는게 당연한건데',
#  '요샌 혼전  이 유행인가 이 ㅈ같은 재앙페미민국에서 수고하네',
#  '생각짧고 멍청한 애들이라',
#  '요즘애들한테 옥상 뛰어다닌썰 풀면 틀딱취급 받겠노',
#  '한심하게 드라마나 처보고 앉아있을때나요 조국 후보자님 우리손으로 지켜야합니다 국민청원에 서명해주세요 이대로가면 토착왜구에 나라 먹힙니다',
#  '악플 잡고 보면 90 한녀들임 ㅋㅋ',
#  '넌 얼굴만 됐어도 대성했을텐데 너무 여자가 세보여서 ',
#  '구하라랑 설리 다 너네가 죽인거잔아 발판은 기자들이 만들어준거고 ㅉㅉ 개한민국 이중성 남탓하는게 종특인가',
#  '문슬람들은 그래도 좋다고 박수쳐요 뭘알겠어요 대가리가 깨졌자나요',
#  '작가는 현실성 제로인듯후덜덜 재결합 결혼생활중 다른 여자 몸과 마음을 주물렀던 전남편과 소오름',
#  '이정도 보고 딸쳤음 자지가 약발 없이 서겠노좆이 주인 잘못 만나 좆대가리 거무튀튀가 될정도로 뽑아낸 모양이노좆대가리야 다음 생엔 주인 잘 만나라',
#  '송탈세와 유애호박의 만남이군',
#  '아줌마들 또 와서 ㅂㄷㅂㄷ거리네 ㅋㅋ',
#  '너 맨날올려서 이런거 척척박사잖어 ㅋㅋㅋ 이색기진짜',
#  '어이고비호감 나오셨네 김지민하고 러브라인 타고 뒤에선 다른여자랑 꽁냥대니 좋았니 ㅋㅋ',
#  '중하위권은 일본애들 많이 꼽아주고 좁밥 좀 많았음',
#  '그전엔 술먹고 할뻔했던적이나 섹스까진 못가거나 한적있긴한데',
#  '이딴 깡패새끼 뽑은 경기도민 수준ㅋㅋ',
#  '니돈으로 대출해주세요꼴통 색햐',
#  '짤 선택이 왤케 틀딱같냐',
#  '응 26살 틀딱',
#  '쓰레기들 퉤',
#  '송중기 정도면 이쁘고 어리고 똑똑한 여자가 줄을 설텐데 돈이야 본인도 충분히 있고 굳이 나이 40다되가는 사람이랑 왜 결혼했나 싶다 그당시 콩깍지가 씌인듯',
#  '좆문가 좃문가 ',
#  '늙은 송혜교',
#  '조아라 판사님 덕분에 여성들의 이미지가 더 나빠졌네요 굳이 전례없는 판결을 하신 이유가 무엇인가요',
#  '저열한 민족성 미국 이승만 박정희라는 변수가 있어서 본래 민족 모습을 잠시 벗어난거였지 원래 우리 민족 본 모습은 북괴임 다시 그길로 가는게 보이잖아',
#  '실검에서 좀 내려라 이 잡것들 조작 ㅈㄴ 하네',
#  '뇌 안돌아가노 게이 ㅋㅋ',
#  '일베쓰레기 지금 정상화 되어가는 과정과 선한 사람들이 맘에 안들고 싫으면 그냥 이민가라 관종짓도 이쁘게 해야지 원 징그러운 새퀴들',
#  '그럼 세울려고 홍준표상상하는거야 노땅취향의 게이였단 말이노',
#  '앜 시발 ㅋㅋ',
#  '폭동은 진압해야지 병신 새끼야',
#  'ㅂㄷㅂㄷ ㅋㅋ 중국 욕하니 ㅂㄷㅂㄷ 하죠 ㅋㅋ',
#  '그런이야기 할수도 있다고 본다 실제로 한것도 아니고참 별거 같고 랄들이넹',
#  '전엔 이상한 옷입고 나오더니 이번엔 음식에 장난하고 자빠졌네 얘 왜이러냐',
#  '개콘폐지되어아쉽네 개그소재로 써면좋겠는데 더러운 대깨문들 공격해서 유투버도 못하것지',
#  '나쁜찐따시키들바이러스만들어서 전세계 작살내고 미리 만들어놓은 백신으로 어렵게 만들었다고 뻥치고 판다 와 진짜핵전쟁각이다',
#  '대한민국 군대나온 수컷들은공짜로 여행보내주고방송촬영하면 백퍼 다 뛴다',
#  '촛불이무슨 전가의 보도냐 대깨문들이 하는짓거리는 그냥 뒷골목 양아치일 뿐이다',
#  '네다음 동부산 틀딱',
#  '테러는 북조선 중앙 일베가 전문이잖아 양심도 없는 샛귀들',
#  '전라도는 인구 소멸 우려될 정도로 인구가 엄청 줄었는데 공무원 10 증가 ㅋㅋ 개같은 사회주의 지상낙원 싸우스 코리아 전라 프라빈스',
#  '씨발넘들',
#  '그래 학원선생 해라 그럼 후배들은 좋지 연재 선생 엉뎅이도 보고 일석이조 이다 엉뎅이 많이 보여줘라 그럼 후배애들 흥분해서 더 엉뎅이보고 더 잘한다',
#  '레아 미만잡 ㅋㅋ총밖에 못쓰는년이 공주지위 하나로 오더존나내림',
#  '니 잘못인데 왜 좆같노 이제부터라도 좋은 삶을 살도록 노력하면 되지',
#  '뭐가 1등 신랑감서울대 나와서 그건 옛말이고 아직 이렇다할 자리매김도없는데',
#  '바꿀수 없으면 이런 잡기사내지마라병신야제목이 더 더럽다 더러워실시간 조회수많으니 가분이 좋으냐',
#  '역겨운 홍어애미뒤진 찌릉내 ㅆ바꺼',
#  '대깨문  정신병자 집단',
#  '개소리하면서 도망가지 말고 근거 가져와 씨발 새끼야 ㅋㅋㅎㅋㅋ',
#  '뭔 씨발 망신만 주구장창 당하네',
#  '댓글들 왜케 부들거리냐ㅋㅋㅋ도끼말 틀린게없는데ㅋㅋ법적인문제가있냐 잠수를탔냐ㅋㅋ',
#  'ㅁㅊ개독들',
#  '개새들이여',
#  '장윤정 노래는 들으면 감정이입되고 같이 눈물 나고 그런데 얜 아주 감정이 메말라서 무슨 기계가 노래하는 것같고 결정적으로 노래를 ㅈ 못부른다 무슨 수로 1위했는지 모르겠다 또 투표로 조작했나',
#  'ㅋㅋ 팩폭 존나 쳐맞고 망신 당하더니 조용하노 착해졌네 엌ㅋㅋ',
#  '일베놈들 부들거리노 ㅋㅋ',
#  '문란한 아이돌이면 엑소나 워너원이겟지 방탄오빠들은 절대아님',
#  '무식하면 용감하다는 말을 몸소 실천해주는 섬숭이들ㅋㅋ',
#  '이젠 시발 특문은 내가 그냥 이해하겠는데 영대문자 넣어서 비번 완성하라는곳은 개씹욕나옴',
#  '여자도 못꼬시고 섹스도 못하는 무능한 찌질이들이 욕구불만에 가득차 여자에게 분노를 표출하고 여혐여성비하 여성차별하는거죠',
#  '이시키 관심끌려고 애쓴다 애써 위아래도 모르는놈이 무슨 ㅉㅉ',
#  '이거 완죤 개새끼네너돈으로 해줘',
#  '좌빨라인 운지고요 지리고요',
#  '브라를 하든 안하든 상관은 없어 그런데 옷이 그리 야시시하게 입고 댕기는데 어느누가 한번 힐끔 안보겠냐 그러면서 시선강간이 싫다고하면 대체 어쩌자는거야 무인도가서 살아야겠지',
#  '송중기 연상녀에게 기빨려서 팍싹 싹은거냐헉왜케 늙음',
#  '두 년놈을 광화문서 화형시키자',
#  '일부러 욕할라고 들어옴 저 ㅁㅣ친 것들 기사 보기싫음 기사화하지도 말아라 지들이 엄청 고귀한 사랑하는줄 ㅎㅎ ㄷㅓ럽고 더 ㄹㅓ운 것들',
#  '지랄이 풍년이네 후쿠시마 산 은 일본 정치하는 놈들이나 쳐먹어라',
#  '우리나라사람들이 대체로 사람을 잘믿어서 사기가 존나많음 전라도것들이 대부분 사기침ㅋ',
#  '1절만해라 존나 처맞기전에',
#  '제대하면 더ㅈ될거임ㄷㄷ 아프리카티비 장악할거임',
#  '먹버전용인듯 이혼남도 한번냠냠 전현무도 어린년만나기전에 한번냠냠 쟤는 저래놓고 똥차보내고 벤츠온다고 믿고있겠지',
#  '진짜 한심한국민들 ㅈㄴ게 할짓거리 없나보네그러니 재앙이나 대통으로 뽑아놓지',
#  '맘충들 부들부들 오지네아이 키우는거 힘들다고 생색 낼 아줌마들 여럿있네아무렴 임창정이 아이들 알아서 크니 부모는 옆에서 구경만 한다 이런 뜻으로 말했을까',
#  '솔까 병원에서 관리받았다쳐도 동안이고 자기관리 열심히 하던데 여자들 괜히 시기하냐 속좁은 것들',
#  '돈도 잘 벌면써 탈세까지 사형시켜라',
#  '쓰레기분리수거가 아직도 안됐네',
#  '응 니도 처단됨 ㅅㄱ',
#  '남편돈으로 호의호식 ㄷㄷ 취집 잘한 케이스',
#  '같이 합의해서 원나잇 해놓구서는 나중엔 성폭행 당했다라 주장했던 사례가 어디 한둘입니까 철저한 검증을 통해서 진위 여부를 가린 다음에 욕해도 늦지 않습니다',
#  '사내대장부가 살다보면 좀 주무를수도 있다 그게 정상적인 사회다',
#  '왜 까 이런 사건이 내이름이랑 같다면  에 한마디 올릴수도 있지  쳐 보지도 않는 ㅅ ㄲ 들이 깐다고 바쁘네',
#  '상또라이 대깨문들이 정치꾼들의 판단을 흐려논다',
#  '비례매국당이라고 해라',
#  '얘 진짜 선 넘으면서 개오버 하더라니 결국엔 사고 쳤네 성규가 아니라 성구더라 아나운서계의 철구 ㅉㅉ',
#  '씨발 노가다꾼새끼 팩트폭행 쳐맞고 부들부들하노 ㅋㅋ',
#  '인기 1도 없이 빨로 여기저기 틀면 나오는 극혐주니어 때문에 사람들이 티비를 안보고 유튜브만 보는 듯',
#  '여가 부칸 중공 이냐 ㅅ ㅂ 민촟탕 쉐퀴들아',
#  '진중권이 좌파인데 바른말해서 유시민 문대앙 패거리 죄국이 아플거다우파가 옳은소리 백날해봤자 개무시한 좌파인데',
#  ...]

# %%
ax = df['content'].str.len().hist(bins=50)

ax.set_xlabel('문장 길이')
ax.set_ylabel('빈도 수')
plt.show()

# %%
#토큰 수
ax = df['content'].str.split().map(lambda x: len(x)).hist(bins=50)

ax.set_xlabel('문장의 토큰 수')
ax.set_ylabel('빈도 수')
# Out:
# Text(0, 0.5, '빈도 수')

# %% [markdown]
# ## 단어 길이 분포

# %%
token_content = [r.split() for r in df['content']]

# %%
content_len = [len(t) for t in token_content]

# %%
content_len_eumjeol = [len(s.replace(' ', '')) for s in df['content']]

# %%
plt.figure(figsize = (12,5))

plt.hist(content_len, bins = 50, alpha=0.5, color="b", label="word")
plt.hist(content_len_eumjeol, bins = 50, alpha=0.5, color="r", label="eumjeol")

plt.yscale('log')
plt.title('sentence Length Histogram')
plt.xlabel('sentence length')
plt.ylabel('number of sentence')
plt.legend(fontsize=14)

# %%
plt.figure(figsize=(12,5))
plt.boxplot([content_len],
            labels = ['Word'],
            showmeans=True)
plt.show()
